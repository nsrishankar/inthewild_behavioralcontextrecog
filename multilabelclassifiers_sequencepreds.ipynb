# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Dataset-parsers-and-cleaning-functions" data-toc-modified-id="Dataset-parsers-and-cleaning-functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Dataset parsers and cleaning functions</a></span><ul class="toc-item"><li><span><a href="#Test-data" data-toc-modified-id="Test-data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Test data</a></span></li><li><span><a href="#Actual-data" data-toc-modified-id="Actual-data-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Actual data</a></span></li></ul></li><li><span><a href="#Sequence-Prediction-LSTM" data-toc-modified-id="Sequence-Prediction-LSTM-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Sequence Prediction LSTM</a></span><ul class="toc-item"><li><span><a href="#Embedding" data-toc-modified-id="Embedding-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Embedding</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Imports

# %%
# Required imports
import os
import numpy as np
import pandas as pd
import seaborn as sns
import gzip
import glob
import pickle
import copy
import math
import itertools
from io import StringIO
import importlib.machinery

from sklearn.metrics import accuracy_score,confusion_matrix,balanced_accuracy_score
from sklearn.metrics import precision_recall_fscore_support,classification_report
#from sklearn.metrics import multilabel_confusion_matrix # Only available in dev .21

# Need Pytorch for multilabel classifications
import torch
from torch.autograd import Variable as V
from torch import nn,optim
import torch.nn.functional as F
import torch.utils.data as utils
#import skorch [Scikit-learn wrapper around Pytorch so allowing for K-fold cross-validation]
from lr_finder import *
random_state=10
np.random.seed(random_state)
# Out:
# /home/nsrishankar/Desktop/Self_study/custom_dl_env/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
# Data location and sample user
prefix='dataset/Extrasensory_uuid_fl_uTAR/'
cross_validation_user_loc='dataset/cv_5_folds/'
user_sample='3600D531-0C55-44A7-AE95-A7A38519464E.features_labels'
done=1 # Pickled files are not created [0]

# %% [markdown]
# # Dataset parsers and cleaning functions

# %%
# Dataset parsers for header/ body for CSVs
def parse_header_of_csv(csv_str):
    # Isolate the headline columns:
    headline = csv_str[:csv_str.index('\n')];
    columns = headline.split(',');

    # The first column should be timestamp:
    assert columns[0] == 'timestamp';
    # The last column should be label_source:
    assert columns[-1] == 'label_source';
    
    # Search for the column of the first label:
    for (ci,col) in enumerate(columns):
        if col.startswith('label:'):
            first_label_ind = ci;
            break;
        pass;

    # Feature columns come after timestamp and before the labels:
    feature_names = columns[1:first_label_ind];
    # Then come the labels, till the one-before-last column:
    label_names = columns[first_label_ind:-1];
    for (li,label) in enumerate(label_names):
        # In the CSV the label names appear with prefix 'label:', but we don't need it after reading the data:
        assert label.startswith('label:');
        label_names[li] = label.replace('label:','');
        pass;
    
    return (feature_names,label_names);

def parse_body_of_csv(csv_str,n_features):
    # Read the entire CSV body into a single numeric matrix:
    full_table = np.loadtxt(StringIO(csv_str),delimiter=',',skiprows=1);
    
    # Timestamp is the primary key for the records (examples):
    timestamps = full_table[:,0].astype(int);
    
    # Read the sensor features:
    X = full_table[:,1:(n_features+1)];
    
    # Read the binary label values, and the 'missing label' indicators:
    trinary_labels_mat = full_table[:,(n_features+1):-1]; # This should have values of either 0., 1. or NaN
    M = np.isnan(trinary_labels_mat); # M is the missing label matrix
    
    #print("M matrix shape:",M.shape)
    #print("Matrix: ",np.argwhere(M))
    
    Y = np.where(M,0,trinary_labels_mat) > 0.; # Y is the label matrix
    
    return (X,Y,M,timestamps);

def read_user_data(directory):
    print('Reading {}'.format(directory.split("/")[-1]))

    # Read the entire csv file of the user:
    with gzip.open(directory,'rb') as fid:
        csv_str = fid.read();
        csv_str = csv_str.decode("utf-8")
        pass;

    (feature_names,label_names) = parse_header_of_csv(csv_str);
    n_features = len(feature_names);
    (X,Y,M,timestamps) = parse_body_of_csv(csv_str,n_features);

    return (X,Y,M,timestamps,feature_names,label_names);

# %%
# Clean labels
def clean_labels(input_label):
    if label.endswith('_'):
        label=label[:-1]+')'
    label=label.replace('__',' (').replace('_',' ')
    label=label[0]+label[1:].lower()
    label=label.replace('i m','I\'m')
    return label

# %%
# Get a summary of the sensor feature
'''
# Summarize features as we are only using phone_acc,phone_gyro,phone_mag,phone_loc,phone_audio,
# phone_app,phone_battery,phone_use,phone_callstat,phone_wifi,phone_lf,phone_time
# We are ignoring the use of the smartwatch features. There are definitely features that will be used
# much more (e.g. than the phone_callstat) but we'll leave that up to the ML algorithm.
'''
def summarize_features(feature_list):
    summary_feature_list=np.empty_like(feature_list)
    for (ind,feature) in enumerate(feature_list):
        if feature.startswith('raw_acc'):
            summary_feature_list[ind]='phone_acc' 
        if feature.startswith('proc_gyro'):
            summary_feature_list[ind]='phone_gyro'
        if feature.startswith('raw_magnet'):
            summary_feature_list[ind]='phone_mag'
        if feature.startswith('watch_acc'):
            summary_feature_list[ind]='watch_acc'
        if feature.startswith('watch_heading'):
            summary_feature_list[ind]='watch_dir'
        if feature.startswith('location'):
            summary_feature_list[ind]='phone_loc'
        if feature.startswith('audio'):
            summary_feature_list[ind]='phone_audio'
        if feature.startswith('discrete:app_state'):
            summary_feature_list[ind]='phone_app'
        if feature.startswith('discrete:battery'):
            summary_feature_list[ind]='phone_battery'
        if feature.startswith('discrete:on'):
            summary_feature_list[ind]='phone_use'
        if feature.startswith('discrete:ringer'):
            summary_feature_list[ind]='phone_callstat'
        if feature.startswith('discrete:wifi'):
            summary_feature_list[ind]='phone_wifi'
        if feature.startswith('lf'):
            summary_feature_list[ind]='phone_lf'
        if feature.startswith('discrete:time'):
            summary_feature_list[ind]='phone_time'

    return summary_feature_list


# Get a summary of the sensor feature along with the original label that was used
def summarize_features_wordy(feature_list):
    summary_feature_list=np.empty((len(feature_list),2),dtype=object)
    
    for (ind,feature) in enumerate(feature_list):
        if feature.startswith('raw_acc'):
            summary_feature_list[ind,0]='phone_acc'
            summary_feature_list[ind,1]=feature
            
        if feature.startswith('proc_gyro'):
            summary_feature_list[ind,0]='phone_gyro'
            summary_feature_list[ind,1]=feature
            
        if feature.startswith('raw_magnet'):
            summary_feature_list[ind,0]='phone_mag'
            summary_feature_list[ind,1]=feature
            
        if feature.startswith('watch_acc'):
            summary_feature_list[ind,0]='watch_acc'
            summary_feature_list[ind,1]=feature
            
        if feature.startswith('watch_heading'):
            summary_feature_list[ind,0]='watch_dir'
            summary_feature_list[ind,1]=feature
            
        if feature.startswith('location'):
            summary_feature_list[ind,0]='phone_loc'
            summary_feature_list[ind,1]=feature
            
        if feature.startswith('audio'):
            summary_feature_list[ind,0]='phone_audio'
            summary_feature_list[ind,1]=feature
            
        if feature.startswith('discrete:app_state'):
            summary_feature_list[ind,0]='phone_app'
            summary_feature_list[ind,1]=feature
            
        if feature.startswith('discrete:battery'):
            summary_feature_list[ind,0]='phone_battery'
            summary_feature_list[ind,1]=feature
            
        if feature.startswith('discrete:on'):
            summary_feature_list[ind,0]='phone_use'
            summary_feature_list[ind,1]=feature
            
        if feature.startswith('discrete:ringer'):
            summary_feature_list[ind,0]='phone_callstat'
            summary_feature_list[ind,1]=feature
            
        if feature.startswith('discrete:wifi'):
            summary_feature_list[ind,0]='phone_wifi'
            summary_feature_list[ind,1]=feature
            
        if feature.startswith('lf'):
            summary_feature_list[ind,0]='phone_lf'
            summary_feature_list[ind,1]=feature
            
        if feature.startswith('discrete:time'):
            summary_feature_list[ind,0]='phone_time'
            summary_feature_list[ind,1]=feature

    return summary_feature_list

# %%
# Custom dictionary class with help for duplicate keys
class Customdictionary(dict):
    def __setitem__(self,key,value):
        try:
            self[key]
        except KeyError:
            super(Customdictionary,self).__setitem__(key,[])
        self[key].append(value)

# %% [markdown]
# ## Test data

# %%
# Reading sample data
sample_loc='{}/{}.csv.gz'.format(prefix,user_sample)
x_user,y_user,missedlabel_user,tstamp_user,featurename_user,labelname_user=read_user_data(sample_loc)

# Dataset summaries for this user
# print('Data shape input for user (Len minutes/num examples, num sensors): ',x_user.shape) # Timestep examples, number of sensors
# print('Label shape for user (Len minutes, num labels): ',y_user.shape,'\n') # Timestep examples, labels

countlabels_user=np.sum(y_user,axis=0) # Column summary
labelname_countlabel_user=zip(labelname_user,countlabels_user) # Zip together names, counts
labelname_countlabel_user=sorted(labelname_countlabel_user,key=lambda row:row[-1],reverse=True)

# print('Sensor feature names:\n')
feature_names=summarize_features(featurename_user)
    
# for i,sensor_feature in enumerate(featurename_user):
#     print('{} :: {} ::--> {}\n'.format(i,feature_names[i],sensor_feature))

# print('Activities and counts:')
# print(labelname_countlabel_user)
# Out:
# Reading 3600D531-0C55-44A7-AE95-A7A38519464E.features_labels.csv.gz

# %%
int2word=dict((integer,word) for integer,word in enumerate(labelname_user))
word2int=dict((word,integer) for integer,word in enumerate(labelname_user))

# %%
df=pd.DataFrame(y_user,columns=labelname_user)
df.groupby(labelname_user).size().reset_index().rename(columns={0:'count'}) # Unique sets of labels
# Out:
#     LYING_DOWN  SITTING  FIX_walking  FIX_running  BICYCLING  SLEEPING  \
# 0        False    False        False        False      False     False
# 1        False    False        False        False      False     False
# 2        False    False        False        False      False     False
# 3        False    False        False        False      False     False
# 4        False    False        False        False      False     False
# 5        False    False        False        False      False     False
# 6        False    False        False        False      False     False
# 7        False    False        False        False      False     False
# 8        False    False        False        False      False     False
# 9        False    False        False        False      False     False
# 10       False    False        False        False      False     False
# 11       False    False        False        False      False     False
# 12       False    False        False        False      False     False
# 13       False    False        False        False      False     False
# 14       False    False        False        False      False     False
# 15       False    False        False        False      False     False
# 16       False    False         True        False      False     False
# 17       False    False         True        False      False     False
# 18       False    False         True        False      False     False
# 19       False    False         True        False      False     False
# 20       False    False         True        False      False     False
# 21       False    False         True        False      False     False
# 22       False    False         True        False      False     False
# 23       False    False         True        False      False     False
# 24       False    False         True        False      False     False
# 25       False    False         True        False      False     False
# 26       False     True        False        False      False     False
# 27       False     True        False        False      False     False
# 28       False     True        False        False      False     False
# 29       False     True        False        False      False     False
# ..         ...      ...          ...          ...        ...       ...
# 35       False     True        False        False      False     False
# 36       False     True        False        False      False     False
# 37       False     True        False        False      False     False
# 38       False     True        False        False      False     False
# 39       False     True        False        False      False     False
# 40       False     True        False        False      False     False
# 41       False     True        False        False      False     False
# 42       False     True        False        False      False     False
# 43       False     True        False        False      False     False
# 44       False     True        False        False      False     False
# 45       False     True        False        False      False     False
# 46       False     True        False        False      False     False
# 47       False     True        False        False      False     False
# 48       False     True        False        False      False     False
# 49       False     True        False        False      False     False
# 50       False     True        False        False      False     False
# 51       False     True        False        False      False     False
# 52       False     True        False        False      False     False
# 53       False     True        False        False      False     False
# 54       False     True        False        False      False     False
# 55       False     True        False        False      False     False
# 56        True    False        False        False      False     False
# 57        True    False        False        False      False     False
# 58        True    False        False        False      False     False
# 59        True    False        False        False      False     False
# 60        True    False        False        False      False      True
# 61        True    False        False        False      False      True
# 62        True    False        False        False      False      True
# 63        True    False        False        False      False      True
# 64        True    False        False        False      False      True
#
#     LAB_WORK  IN_CLASS  IN_A_MEETING  LOC_main_workplace  ...    \
# 0      False     False         False               False  ...
# 1      False     False         False               False  ...
# 2      False     False         False               False  ...
# 3      False     False         False               False  ...
# 4      False     False         False               False  ...
# 5      False     False         False               False  ...
# 6      False     False         False               False  ...
# 7      False     False         False               False  ...
# 8      False     False         False               False  ...
# 9      False     False         False               False  ...
# 10     False     False         False               False  ...
# 11     False     False         False               False  ...
# 12     False     False         False               False  ...
# 13     False     False         False               False  ...
# 14     False     False         False               False  ...
# 15     False     False         False               False  ...
# 16     False     False         False               False  ...
# 17     False     False         False               False  ...
# 18     False     False         False               False  ...
# 19     False     False         False               False  ...
# 20     False     False         False               False  ...
# 21     False     False         False               False  ...
# 22     False     False         False               False  ...
# 23     False     False         False               False  ...
# 24     False     False         False               False  ...
# 25     False     False         False               False  ...
# 26     False     False         False               False  ...
# 27     False     False         False               False  ...
# 28     False     False         False               False  ...
# 29     False     False         False               False  ...
# ..       ...       ...           ...                 ...  ...
# 35     False     False         False               False  ...
# 36     False     False         False               False  ...
# 37     False     False         False               False  ...
# 38     False     False         False               False  ...
# 39     False     False         False               False  ...
# 40     False     False         False               False  ...
# 41     False     False         False               False  ...
# 42     False     False         False               False  ...
# 43     False     False         False               False  ...
# 44     False     False         False               False  ...
# 45     False     False         False               False  ...
# 46     False     False         False               False  ...
# 47     False     False         False               False  ...
# 48     False     False         False               False  ...
# 49     False     False         False               False  ...
# 50     False     False         False               False  ...
# 51     False     False         False               False  ...
# 52     False     False         False               False  ...
# 53     False     False         False               False  ...
# 54     False     False          True               False  ...
# 55     False      True         False               False  ...
# 56     False     False         False               False  ...
# 57     False     False         False               False  ...
# 58     False     False         False               False  ...
# 59     False     False         False               False  ...
# 60     False     False         False               False  ...
# 61     False     False         False               False  ...
# 62     False     False         False               False  ...
# 63     False     False         False               False  ...
# 64     False     False         False               False  ...
#
#     STAIRS_-_GOING_DOWN  ELEVATOR  OR_standing  AT_SCHOOL  PHONE_IN_HAND  \
# 0                 False     False        False      False          False
# 1                 False     False         True      False          False
# 2                 False     False         True      False          False
# 3                 False     False        False      False          False
# 4                 False     False         True      False          False
# 5                 False     False         True      False          False
# 6                 False     False         True      False          False
# 7                 False     False         True      False          False
# 8                 False     False         True      False          False
# 9                 False     False         True      False          False
# 10                False      True         True      False           True
# 11                False     False         True      False          False
# 12                False     False         True      False          False
# 13                False     False         True      False          False
# 14                False     False         True      False          False
# 15                False     False         True      False          False
# 16                False     False        False      False          False
# 17                False     False        False      False          False
# 18                False     False        False      False          False
# 19                False     False        False       True          False
# 20                False     False        False      False          False
# 21                False     False        False       True          False
# 22                False     False        False      False          False
# 23                False     False        False      False          False
# 24                False     False        False      False          False
# 25                False     False        False      False          False
# 26                False     False        False      False          False
# 27                False     False        False      False          False
# 28                False     False        False      False          False
# 29                False     False        False       True          False
# ..                  ...       ...          ...        ...            ...
# 35                False     False        False      False          False
# 36                False     False        False      False          False
# 37                False     False        False      False          False
# 38                False     False        False      False          False
# 39                False     False        False      False          False
# 40                False     False        False      False          False
# 41                False     False        False      False          False
# 42                False     False        False      False          False
# 43                False     False        False      False           True
# 44                False     False        False      False           True
# 45                False     False        False      False          False
# 46                False     False        False      False          False
# 47                False     False        False      False          False
# 48                False     False        False      False          False
# 49                False     False        False      False          False
# 50                False     False        False      False          False
# 51                False     False        False      False          False
# 52                False     False        False      False          False
# 53                False     False        False      False          False
# 54                False     False        False       True          False
# 55                False     False        False       True          False
# 56                False     False        False      False          False
# 57                False     False        False      False          False
# 58                False     False        False      False          False
# 59                False     False        False      False           True
# 60                False     False        False      False          False
# 61                False     False        False      False          False
# 62                False     False        False      False          False
# 63                False     False        False      False          False
# 64                False     False        False      False          False
#
#     PHONE_IN_BAG  PHONE_ON_TABLE  WITH_CO-WORKERS  WITH_FRIENDS  count
# 0          False           False            False         False    106
# 1          False           False            False         False      3
# 2          False           False            False          True     30
# 3          False           False            False         False   1329
# 4          False           False            False         False     59
# 5           True           False            False         False      7
# 6          False           False            False          True     15
# 7          False           False            False         False     41
# 8          False           False            False          True    121
# 9          False           False            False         False      1
# 10         False           False            False         False      1
# 11         False            True            False         False     15
# 12         False            True            False         False      8
# 13          True           False            False         False     26
# 14         False           False            False         False     52
# 15         False            True            False         False      5
# 16         False           False            False         False     11
# 17         False           False            False         False     15
# 18         False           False            False         False     15
# 19         False           False            False         False      2
# 20         False           False            False         False      1
# 21         False           False            False         False     21
# 22         False           False            False         False     47
# 23         False           False            False         False      1
# 24         False           False            False         False      6
# 25         False           False            False         False     13
# 26         False            True            False         False     69
# 27         False           False            False         False     14
# 28         False            True            False          True     93
# 29         False           False            False         False      1
# ..           ...             ...              ...           ...    ...
# 35         False           False            False          True      1
# 36         False           False            False         False     43
# 37         False           False            False          True     93
# 38         False           False            False         False     31
# 39         False           False            False          True     31
# 40         False           False            False         False    103
# 41         False           False            False         False     40
# 42         False            True            False          True    495
# 43         False           False            False         False      8
# 44         False           False            False         False      4
# 45         False           False            False         False     84
# 46         False           False            False         False     20
# 47         False            True            False          True     35
# 48         False           False            False         False     31
# 49         False            True            False         False    172
# 50         False           False            False         False     38
# 51         False           False            False         False      4
# 52         False           False            False          True     23
# 53         False           False            False          True     16
# 54         False            True            False         False     27
# 55         False           False            False         False     54
# 56         False           False            False          True    145
# 57         False            True            False         False     77
# 58         False           False            False         False     42
# 59         False           False            False          True     51
# 60         False            True            False         False     17
# 61         False            True            False          True     21
# 62         False           False            False         False    108
# 63         False            True            False         False    640
# 64         False            True            False          True    235
#
# [65 rows x 52 columns]

# %%
df_test=df.astype(int)

# %%
list_arr=[]
for i in range(0, len(df_test)):
    temp_arr=df.iloc[i].values.astype(int)
    temp_arr=np.multiply(temp_arr,np.arange(51)) #Column position value wherever the label was 1
    temp_arr=temp_arr[temp_arr>0]
    list_arr.append(temp_arr)

# %%
list_arr_orig=copy.deepcopy(list_arr)
list_arr_mod=[]
for i in range(0,len(list_arr)):
    check=[list_arr[i-2].tolist(),list_arr[i-1].tolist()]
    if i>=2:
        arr_value=list_arr[i].tolist()
        if ((arr_value!=check[-1]) or (arr_value!=check[0])):
            list_arr_mod.append(arr_value)
    else:
        list_arr_mod.append(list_arr[i])

# %%
level_dict={}
for i in range(len(list_arr_mod)):
    level_dict[i]=list_arr_mod[i]

# %%
string_sequence=''
for k,v in level_dict.items():
    for v1 in v:
        string_sequence=string_sequence+'_'+str(v1)

# %%
def permute(lists,prefix=''):
#     global out
    if not lists:
        print(prefix)
        return
        
    first=lists[0]
    rest=lists[1:]
    for letter in first:
        permute(rest,prefix+str(letter)+'_')

# %%
string_sequence
# Out:
# '_1_8_34_45_48_1_8_34_45_48_2_2_2_10_16_10_16_44_1_10_16_34_48_50_1_10_16_34_48_50_10_16_43_44_46_2_10_16_18_2_10_16_18_2_18_2_10_16_18_2_10_16_18_2_18_2_18_10_19_40_44_10_19_40_44_18_44_18_44_16_16_16_16_10_16_28_34_36_46_50_10_16_28_34_36_46_50_1_10_37_46_1_10_37_46_1_10_16_37_46_1_10_16_37_46_1_10_37_46_1_10_16_37_46_1_10_16_37_46_10_16_24_44_47_10_16_24_44_47_10_24_44_47_10_24_44_47_10_16_24_44_47_10_24_44_47_10_24_44_47_10_16_34_44_48_10_16_34_44_48_16_10_16_20_44_48_10_16_20_44_48_1_10_16_18_28_36_1_10_16_18_28_36_5_10_16_48_1_28_36_45_1_12_18_33_34_50_1_28_36_48_50_1_28_36_48_50_10_16_28_36_10_16_28_36_1_10_48_50_1_10_48_50_1_12_15_1_12_15_10_21_44_50_10_21_44_50_1_12_15_50_1_12_15_50_1_23_36_1_23_36_1_10_16_23_36_1_10_16_23_36_1_10_16_18_23_28_34_36_50_1_10_16_18_23_28_34_36_50_1_18_23_28_34_36_50_1_10_16_18_23_28_34_36_50_1_18_23_28_34_36_50_1_10_16_18_23_28_34_36_50_1_18_23_28_34_36_50_1_10_16_18_23_28_34_36_50_1_10_16_18_23_28_34_36_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_5_10_48_50_5_10_16_48_50_5_10_16_48_50_1_15_21_34_50_1_10_15_16_21_34_50_1_10_15_16_21_34_50_1_15_21_34_50_1_15_21_34_50_1_10_16_28_36_1_10_16_28_36_10_16_28_48_10_16_28_48_10_16_28_36_10_16_28_36_10_16_24_39_44_10_16_24_39_44_1_12_15_18_1_12_15_18_11_18_33_44_11_18_33_44_1_17_36_1_17_36_1_12_15_34_1_12_15_34_1_28_34_48_50_1_28_34_48_50_1_10_48_50_1_10_48_50_18_28_36_50_18_28_36_50_1_12_15_18_34_1_12_15_18_34_1_48_1_48_1_12_15_34_50_1_12_15_34_50_18_34_44_50_18_34_44_50_5_10_16_48_5_10_16_48_1_10_16_36_1_10_16_36_1_36_1_36_1_10_16_36_1_36_1_10_16_36_1_10_16_36_1_36_1_36_2_11_18_33_2_11_18_33_2_16_18_33_2_11_18_33_2_11_18_33_10_18_19_40_44_50_10_18_19_40_44_50_2_18_21_33_2_18_21_33_2_10_16_18_21_33_2_10_16_18_21_33_2_18_21_33_2_10_16_18_21_33_2_10_16_18_21_33_2_18_21_33_2_18_21_33_2_10_16_18_21_33_2_18_21_33_2_18_21_33_2_10_16_18_21_33_2_10_16_18_21_33_1_10_16_28_36_48_1_10_16_28_36_48_16_16_16_16_16_16_16_16_16_16_16_16_16_16_16_16_16_16_16_16_16_16_16_16_16_16_5_10_16_48_10_16_39_44_48_10_16_39_44_48_2_16_18_45_2_16_18_45_2_11_18_45_2_11_18_45_1_7_10_18_45_1_7_10_18_45_5_10_16_5_10_16_1_10_16_34_1_10_16_34_1_10_16_28_36_48_1_10_16_28_36_48_16_16_16_16_16_16_16_5_10_16_48_5_10_16_48_16_16_5_10_16_48_5_10_16_48_5_10_48_5_10_48_2_11_18_45_2_11_18_45'

# %% [markdown]
# ## Actual data

# %%
globs=glob.glob('dataset/Extrasensory_uuid_fl_uTAR/*')
for g in globs:
    fname=g.split('/')[-1].split('.')[0]
    fname='dataset/sequence_strings/{}.txt'.format(fname)
    x_user,y_user,missedlabel_user,tstamp_user,featurename_user,labelname_user=read_user_data(g)
    
        # Dataset summaries for this user
    print('Data shape input for user (Len minutes/num examples, num sensors): ',x_user.shape) # Timestep examples, number of sensors
    print('Label shape for user (Len minutes, num labels): ',y_user.shape,'\n') # Timestep examples, labels

    countlabels_user=np.sum(y_user,axis=0) # Column summary
    labelname_countlabel_user=zip(labelname_user,countlabels_user) # Zip together names, counts
    labelname_countlabel_user=sorted(labelname_countlabel_user,key=lambda row:row[-1],reverse=True)

    print('Sensor feature names:\n')
    feature_names=summarize_features(featurename_user)

    # for i,sensor_feature in enumerate(featurename_user):
    #     print('{} :: {} ::--> {}\n'.format(i,feature_names[i],sensor_feature))

    print('Activities and counts:')
    print(labelname_countlabel_user)
    
    df=pd.DataFrame(y_user,columns=labelname_user)
    df_test=df.astype(int)
    
    list_arr=[]
    for i in range(0, len(df_test)):
        temp_arr=df.iloc[i].values.astype(int)
        temp_arr=np.multiply(temp_arr,np.arange(51)) #Column position value wherever the label was 1
        temp_arr=temp_arr[temp_arr>0]
        list_arr.append(temp_arr)
        
    list_arr_orig=copy.deepcopy(list_arr)
    list_arr_mod=[]
    for i in range(0,len(list_arr)):
        check=[list_arr[i-2].tolist(),list_arr[i-1].tolist()]
        if i>=2:
            arr_value=list_arr[i].tolist()
            if ((arr_value!=check[-1]) or (arr_value!=check[0])):
                list_arr_mod.append(arr_value)
        else:
            list_arr_mod.append(list_arr[i])
    
    level_dict={}
    for i in range(len(list_arr_mod)):
        level_dict[i]=list_arr_mod[i]
        
    string_sequence=''
    for k,v in level_dict.items():
        for v1 in v:
            string_sequence=string_sequence+'_'+str(v1)
            
    f=open(fname,"w")
    f.write(string_sequence)
    f.close()
# Out:
# Reading 3600D531-0C55-44A7-AE95-A7A38519464E.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (5203, 225)
# Label shape for user (Len minutes, num labels):  (5203, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('LOC_home', 3040), ('OR_indoors', 2487), ('PHONE_ON_TABLE', 2179), ('SITTING', 1916), ('WITH_FRIENDS', 1730), ('LYING_DOWN', 1336), ('SLEEPING', 1021), ('WATCHING_TV', 912), ('EATING', 762), ('PHONE_IN_POCKET', 706), ('TALKING', 638), ('DRIVE_-_I_M_A_PASSENGER', 409), ('OR_standing', 384), ('IN_A_CAR', 342), ('OR_exercise', 162), ('AT_THE_GYM', 162), ('SINGING', 136), ('FIX_walking', 132), ('OR_outside', 127), ('SHOPPING', 111), ('AT_SCHOOL', 105), ('BATHING_-_SHOWER', 85), ('DRESSING', 67), ('DRINKING__ALCOHOL_', 66), ('PHONE_IN_HAND', 64), ('FIX_restaurant', 59), ('IN_CLASS', 54), ('PHONE_IN_BAG', 33), ('IN_A_MEETING', 27), ('TOILET', 12), ('COOKING', 5), ('ELEVATOR', 1), ('FIX_running', 0), ('BICYCLING', 0), ('LAB_WORK', 0), ('LOC_main_workplace', 0), ('ON_A_BUS', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('STROLLING', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('COMPUTER_WORK', 0), ('GROOMING', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('WITH_CO-WORKERS', 0)]
# Reading 8023FE1A-D3B0-4E2C-A57A-9321B7FC755F.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (9189, 225)
# Label shape for user (Len minutes, num labels):  (9189, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 4506), ('LOC_home', 3534), ('LYING_DOWN', 3036), ('SITTING', 2765), ('SLEEPING', 2292), ('AT_SCHOOL', 1451), ('OR_standing', 1398), ('COMPUTER_WORK', 978), ('LOC_main_workplace', 729), ('WITH_FRIENDS', 412), ('BICYCLING', 362), ('OR_exercise', 362), ('IN_A_CAR', 336), ('TALKING', 307), ('DRIVE_-_I_M_THE_DRIVER', 277), ('FIX_walking', 275), ('GROOMING', 217), ('EATING', 213), ('PHONE_ON_TABLE', 200), ('COOKING', 191), ('PHONE_IN_POCKET', 187), ('SURFING_THE_INTERNET', 155), ('WITH_CO-WORKERS', 152), ('CLEANING', 137), ('TOILET', 121), ('SHOPPING', 106), ('PHONE_IN_BAG', 100), ('BATHING_-_SHOWER', 78), ('DRIVE_-_I_M_A_PASSENGER', 59), ('IN_A_MEETING', 57), ('PHONE_IN_HAND', 50), ('WASHING_DISHES', 25), ('DRESSING', 13), ('DOING_LAUNDRY', 10), ('STAIRS_-_GOING_UP', 1), ('FIX_running', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('OR_outside', 0), ('ON_A_BUS', 0), ('FIX_restaurant', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('WATCHING_TV', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0)]
# Reading 86A4F379-B305-473D-9D83-FC7D800180EF.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (10738, 225)
# Label shape for user (Len minutes, num labels):  (10738, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 2652), ('OR_standing', 2085), ('LYING_DOWN', 1939), ('LOC_home', 1903), ('SLEEPING', 1876), ('LOC_main_workplace', 1519), ('COMPUTER_WORK', 1041), ('TALKING', 837), ('EATING', 622), ('PHONE_ON_TABLE', 443), ('DRIVE_-_I_M_THE_DRIVER', 425), ('IN_A_CAR', 388), ('PHONE_IN_BAG', 343), ('SURFING_THE_INTERNET', 340), ('SITTING', 207), ('FIX_walking', 175), ('PHONE_IN_HAND', 172), ('BATHING_-_SHOWER', 136), ('GROOMING', 136), ('DRESSING', 136), ('OR_outside', 120), ('TOILET', 85), ('WATCHING_TV', 35), ('SHOPPING', 33), ('AT_A_PARTY', 26), ('AT_A_BAR', 26), ('PHONE_IN_POCKET', 25), ('FIX_running', 0), ('BICYCLING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('IN_A_MEETING', 0), ('ON_A_BUS', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('OR_exercise', 0), ('COOKING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('LOC_beach', 0), ('SINGING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('AT_SCHOOL', 0), ('WITH_CO-WORKERS', 0), ('WITH_FRIENDS', 0)]
# Reading 1538C99F-BA1E-4EFB-A949-6C7C47701B20.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (6549, 225)
# Label shape for user (Len minutes, num labels):  (6549, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 4867), ('LOC_home', 4577), ('SITTING', 2735), ('LYING_DOWN', 2412), ('SLEEPING', 2286), ('AT_SCHOOL', 1064), ('COMPUTER_WORK', 1013), ('PHONE_IN_HAND', 689), ('FIX_walking', 662), ('OR_standing', 617), ('TALKING', 403), ('IN_A_MEETING', 271), ('IN_CLASS', 269), ('EATING', 256), ('OR_exercise', 235), ('WITH_FRIENDS', 227), ('AT_A_PARTY', 132), ('WATCHING_TV', 115), ('FIX_restaurant', 95), ('BATHING_-_SHOWER', 60), ('PHONE_IN_POCKET', 52), ('CLEANING', 52), ('WITH_CO-WORKERS', 52), ('TOILET', 48), ('DRESSING', 48), ('STAIRS_-_GOING_UP', 27), ('FIX_running', 0), ('BICYCLING', 0), ('LAB_WORK', 0), ('LOC_main_workplace', 0), ('OR_outside', 0), ('IN_A_CAR', 0), ('ON_A_BUS', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('COOKING', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('GROOMING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_BAG', 0), ('PHONE_ON_TABLE', 0)]
# Reading 11B5EC4D-4133-4289-B475-4E737182A406.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (8845, 225)
# Label shape for user (Len minutes, num labels):  (8845, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('LOC_home', 4706), ('PHONE_ON_TABLE', 4410), ('OR_indoors', 3799), ('LYING_DOWN', 2946), ('SLEEPING', 2525), ('LOC_main_workplace', 1769), ('SITTING', 1694), ('OR_standing', 637), ('COMPUTER_WORK', 636), ('PHONE_IN_BAG', 623), ('IN_A_CAR', 432), ('DRIVE_-_I_M_THE_DRIVER', 430), ('TALKING', 348), ('IN_A_MEETING', 330), ('PHONE_IN_HAND', 270), ('OR_exercise', 251), ('AT_THE_GYM', 189), ('FIX_walking', 164), ('CLEANING', 153), ('OR_outside', 128), ('LOC_beach', 95), ('SURFING_THE_INTERNET', 92), ('DOING_LAUNDRY', 82), ('BICYCLING', 62), ('EATING', 48), ('SHOPPING', 36), ('WATCHING_TV', 30), ('COOKING', 23), ('BATHING_-_SHOWER', 11), ('STAIRS_-_GOING_UP', 3), ('DRIVE_-_I_M_A_PASSENGER', 2), ('FIX_running', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('ON_A_BUS', 0), ('FIX_restaurant', 0), ('PHONE_IN_POCKET', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('WASHING_DISHES', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('SINGING', 0), ('TOILET', 0), ('GROOMING', 0), ('DRESSING', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('AT_SCHOOL', 0), ('WITH_CO-WORKERS', 0), ('WITH_FRIENDS', 0)]
# Reading 74B86067-5D4B-43CF-82CF-341B76BEA0F4.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (7298, 225)
# Label shape for user (Len minutes, num labels):  (7298, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('LOC_home', 5757), ('OR_indoors', 5448), ('PHONE_ON_TABLE', 3771), ('SITTING', 2627), ('LYING_DOWN', 2500), ('SLEEPING', 2485), ('SURFING_THE_INTERNET', 1860), ('OR_standing', 918), ('OR_exercise', 787), ('BICYCLING', 692), ('PHONE_IN_POCKET', 669), ('EATING', 344), ('CLEANING', 320), ('WATCHING_TV', 270), ('IN_A_MEETING', 243), ('COOKING', 131), ('FIX_running', 88), ('IN_A_CAR', 81), ('TOILET', 79), ('DRESSING', 77), ('DRIVE_-_I_M_THE_DRIVER', 73), ('SHOPPING', 69), ('GROOMING', 30), ('STROLLING', 17), ('FIX_walking', 15), ('WASHING_DISHES', 13), ('AT_SCHOOL', 12), ('OR_outside', 8), ('LAB_WORK', 0), ('IN_CLASS', 0), ('LOC_main_workplace', 0), ('ON_A_BUS', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('DOING_LAUNDRY', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('TALKING', 0), ('COMPUTER_WORK', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_HAND', 0), ('PHONE_IN_BAG', 0), ('WITH_CO-WORKERS', 0), ('WITH_FRIENDS', 0)]
# Reading 4FC32141-E888-4BFF-8804-12559A491D8C.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (4979, 225)
# Label shape for user (Len minutes, num labels):  (4979, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 3153), ('LYING_DOWN', 2096), ('LOC_home', 1966), ('SLEEPING', 1860), ('PHONE_ON_TABLE', 1588), ('SITTING', 1004), ('OR_standing', 763), ('LOC_main_workplace', 730), ('OR_outside', 464), ('PHONE_IN_POCKET', 449), ('OR_exercise', 423), ('BICYCLING', 413), ('LAB_WORK', 362), ('FIX_walking', 298), ('EATING', 101), ('LOC_beach', 94), ('DRIVE_-_I_M_A_PASSENGER', 60), ('COOKING', 60), ('DRIVE_-_I_M_THE_DRIVER', 55), ('COMPUTER_WORK', 52), ('AT_SCHOOL', 48), ('IN_A_MEETING', 47), ('TALKING', 37), ('GROOMING', 37), ('DRESSING', 16), ('BATHING_-_SHOWER', 13), ('WASHING_DISHES', 11), ('FIX_running', 10), ('PHONE_IN_BAG', 5), ('TOILET', 4), ('IN_CLASS', 0), ('IN_A_CAR', 0), ('ON_A_BUS', 0), ('FIX_restaurant', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WATCHING_TV', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('SINGING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_HAND', 0), ('WITH_CO-WORKERS', 0), ('WITH_FRIENDS', 0)]
# Reading B9724848-C7E2-45F4-9B3F-A1F38D864495.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (7626, 225)
# Label shape for user (Len minutes, num labels):  (7626, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 4893), ('LOC_home', 3066), ('SITTING', 2961), ('LYING_DOWN', 2554), ('WITH_FRIENDS', 2455), ('SLEEPING', 2422), ('TALKING', 1414), ('PHONE_IN_BAG', 1225), ('COMPUTER_WORK', 1035), ('OR_standing', 1010), ('AT_SCHOOL', 770), ('FIX_walking', 714), ('OR_outside', 584), ('EATING', 457), ('LOC_main_workplace', 369), ('PHONE_IN_POCKET', 360), ('PHONE_ON_TABLE', 335), ('CLEANING', 330), ('IN_CLASS', 286), ('PHONE_IN_HAND', 220), ('DRIVE_-_I_M_A_PASSENGER', 217), ('GROOMING', 187), ('WITH_CO-WORKERS', 143), ('DOING_LAUNDRY', 96), ('BATHING_-_SHOWER', 87), ('SURFING_THE_INTERNET', 69), ('ON_A_BUS', 65), ('TOILET', 56), ('WATCHING_TV', 49), ('SHOPPING', 44), ('FIX_running', 13), ('OR_exercise', 13), ('WASHING_DISHES', 5), ('ELEVATOR', 1), ('BICYCLING', 0), ('LAB_WORK', 0), ('IN_A_MEETING', 0), ('IN_A_CAR', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('FIX_restaurant', 0), ('COOKING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0)]
# Reading A76A5AF5-5A93-4CF2-A16E-62353BB70E8A.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (7520, 225)
# Label shape for user (Len minutes, num labels):  (7520, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 4009), ('PHONE_ON_TABLE', 3987), ('LOC_home', 3645), ('LYING_DOWN', 2849), ('SLEEPING', 2690), ('SITTING', 2472), ('AT_SCHOOL', 1984), ('PHONE_IN_POCKET', 1958), ('LOC_main_workplace', 1698), ('LAB_WORK', 1351), ('OR_standing', 1207), ('FIX_walking', 800), ('EATING', 459), ('WATCHING_TV', 448), ('WITH_CO-WORKERS', 437), ('IN_A_CAR', 250), ('DRIVE_-_I_M_THE_DRIVER', 202), ('PHONE_IN_HAND', 164), ('OR_exercise', 154), ('SURFING_THE_INTERNET', 153), ('FIX_restaurant', 145), ('AT_THE_GYM', 98), ('BATHING_-_SHOWER', 97), ('TOILET', 93), ('FIX_running', 88), ('IN_A_MEETING', 81), ('GROOMING', 76), ('OR_outside', 73), ('DRINKING__ALCOHOL_', 58), ('BICYCLING', 56), ('DOING_LAUNDRY', 56), ('TALKING', 47), ('DRESSING', 42), ('COOKING', 22), ('ON_A_BUS', 16), ('WASHING_DISHES', 16), ('CLEANING', 15), ('STAIRS_-_GOING_DOWN', 1), ('IN_CLASS', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('SHOPPING', 0), ('STROLLING', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('COMPUTER_WORK', 0), ('STAIRS_-_GOING_UP', 0), ('ELEVATOR', 0), ('PHONE_IN_BAG', 0), ('WITH_FRIENDS', 0)]
# Reading 96A358A0-FFF2-4239-B93E-C7425B901B47.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (5819, 225)
# Label shape for user (Len minutes, num labels):  (5819, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 1470), ('LOC_home', 1434), ('PHONE_ON_TABLE', 1309), ('LYING_DOWN', 1110), ('SLEEPING', 1082), ('SITTING', 557), ('PHONE_IN_POCKET', 366), ('AT_SCHOOL', 210), ('WATCHING_TV', 189), ('TALKING', 152), ('EATING', 102), ('CLEANING', 94), ('OR_standing', 92), ('TOILET', 83), ('ON_A_BUS', 63), ('IN_CLASS', 61), ('SURFING_THE_INTERNET', 43), ('PHONE_IN_HAND', 40), ('IN_A_MEETING', 31), ('FIX_walking', 28), ('GROOMING', 23), ('OR_outside', 22), ('WITH_FRIENDS', 22), ('SHOPPING', 11), ('FIX_running', 0), ('BICYCLING', 0), ('LAB_WORK', 0), ('LOC_main_workplace', 0), ('IN_A_CAR', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('OR_exercise', 0), ('COOKING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('COMPUTER_WORK', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_BAG', 0), ('WITH_CO-WORKERS', 0)]
# Reading 665514DE-49DC-421F-8DCB-145D0B2609AD.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (9167, 225)
# Label shape for user (Len minutes, num labels):  (9167, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('PHONE_ON_TABLE', 5235), ('SITTING', 3044), ('LYING_DOWN', 2548), ('LOC_home', 2358), ('OR_indoors', 2061), ('TALKING', 1826), ('WITH_FRIENDS', 1654), ('PHONE_IN_POCKET', 1304), ('OR_outside', 1184), ('FIX_walking', 1181), ('COMPUTER_WORK', 1080), ('OR_standing', 621), ('LOC_main_workplace', 483), ('COOKING', 444), ('WATCHING_TV', 275), ('PHONE_IN_HAND', 240), ('EATING', 218), ('ON_A_BUS', 141), ('SHOPPING', 124), ('TOILET', 67), ('DRESSING', 67), ('AT_SCHOOL', 65), ('IN_A_MEETING', 27), ('IN_A_CAR', 20), ('FIX_running', 8), ('OR_exercise', 8), ('WASHING_DISHES', 2), ('BICYCLING', 0), ('SLEEPING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('GROOMING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_BAG', 0), ('WITH_CO-WORKERS', 0)]
# Reading BE3CA5A6-A561-4BBD-B7C9-5DF6805400FC.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (8309, 225)
# Label shape for user (Len minutes, num labels):  (8309, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('LYING_DOWN', 2742), ('SITTING', 2521), ('OR_indoors', 1859), ('PHONE_ON_TABLE', 943), ('AT_SCHOOL', 732), ('IN_CLASS', 447), ('FIX_walking', 273), ('OR_standing', 259), ('PHONE_IN_HAND', 202), ('DRIVE_-_I_M_THE_DRIVER', 158), ('SURFING_THE_INTERNET', 103), ('TALKING', 97), ('COOKING', 94), ('BICYCLING', 92), ('OR_exercise', 92), ('PHONE_IN_POCKET', 90), ('IN_A_CAR', 67), ('EATING', 59), ('CLEANING', 32), ('WITH_FRIENDS', 31), ('BATHING_-_SHOWER', 24), ('FIX_restaurant', 20), ('WASHING_DISHES', 16), ('OR_outside', 15), ('IN_A_MEETING', 5), ('GROOMING', 5), ('STROLLING', 4), ('TOILET', 3), ('STAIRS_-_GOING_DOWN', 2), ('FIX_running', 0), ('SLEEPING', 0), ('LAB_WORK', 0), ('LOC_main_workplace', 0), ('ON_A_BUS', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('LOC_home', 0), ('SHOPPING', 0), ('DRINKING__ALCOHOL_', 0), ('DOING_LAUNDRY', 0), ('WATCHING_TV', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('COMPUTER_WORK', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('ELEVATOR', 0), ('PHONE_IN_BAG', 0), ('WITH_CO-WORKERS', 0)]
# Reading A5A30F76-581E-4757-97A2-957553A2C6AA.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (1667, 225)
# Label shape for user (Len minutes, num labels):  (1667, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 810), ('PHONE_ON_TABLE', 730), ('LOC_home', 715), ('SITTING', 685), ('LYING_DOWN', 585), ('SLEEPING', 517), ('PHONE_IN_POCKET', 403), ('COMPUTER_WORK', 380), ('LOC_main_workplace', 335), ('OR_standing', 296), ('IN_A_CAR', 154), ('LAB_WORK', 123), ('FIX_walking', 95), ('EATING', 68), ('OR_exercise', 46), ('AT_SCHOOL', 43), ('AT_THE_GYM', 42), ('ELEVATOR', 35), ('TALKING', 29), ('IN_A_MEETING', 23), ('TOILET', 22), ('CLEANING', 17), ('COOKING', 15), ('PHONE_IN_HAND', 15), ('SHOPPING', 8), ('BATHING_-_SHOWER', 8), ('FIX_running', 4), ('STAIRS_-_GOING_UP', 2), ('STAIRS_-_GOING_DOWN', 2), ('BICYCLING', 0), ('IN_CLASS', 0), ('OR_outside', 0), ('ON_A_BUS', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('WATCHING_TV', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('GROOMING', 0), ('DRESSING', 0), ('PHONE_IN_BAG', 0), ('WITH_CO-WORKERS', 0), ('WITH_FRIENDS', 0)]
# Reading 27E04243-B138-4F40-A164-F40B60165CF3.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (4927, 225)
# Label shape for user (Len minutes, num labels):  (4927, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 1948), ('SITTING', 1184), ('PHONE_ON_TABLE', 1137), ('LYING_DOWN', 1115), ('SLEEPING', 1115), ('PHONE_IN_HAND', 864), ('SURFING_THE_INTERNET', 845), ('TALKING', 673), ('WITH_FRIENDS', 662), ('LOC_home', 610), ('OR_standing', 379), ('COMPUTER_WORK', 335), ('OR_outside', 278), ('FIX_walking', 207), ('STAIRS_-_GOING_UP', 192), ('STAIRS_-_GOING_DOWN', 192), ('IN_CLASS', 174), ('PHONE_IN_BAG', 117), ('EATING', 108), ('AT_SCHOOL', 52), ('TOILET', 51), ('ON_A_BUS', 46), ('WATCHING_TV', 45), ('BATHING_-_SHOWER', 32), ('CLEANING', 15), ('IN_A_MEETING', 7), ('FIX_running', 0), ('BICYCLING', 0), ('LAB_WORK', 0), ('LOC_main_workplace', 0), ('IN_A_CAR', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('PHONE_IN_POCKET', 0), ('OR_exercise', 0), ('COOKING', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('GROOMING', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('ELEVATOR', 0), ('WITH_CO-WORKERS', 0)]
# Reading 0E6184E1-90C0-48EE-B25A-F1ECB7B9714E.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (7521, 225)
# Label shape for user (Len minutes, num labels):  (7521, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 4549), ('SITTING', 3089), ('LOC_home', 2494), ('TALKING', 2438), ('WITH_FRIENDS', 2418), ('LYING_DOWN', 1989), ('FIX_walking', 1532), ('SLEEPING', 1312), ('AT_SCHOOL', 1069), ('OR_standing', 866), ('WITH_CO-WORKERS', 840), ('CLEANING', 828), ('IN_CLASS', 647), ('OR_outside', 546), ('LOC_main_workplace', 517), ('EATING', 376), ('COOKING', 331), ('SURFING_THE_INTERNET', 231), ('FIX_restaurant', 137), ('DRESSING', 118), ('GROOMING', 116), ('PHONE_ON_TABLE', 107), ('TOILET', 96), ('BATHING_-_SHOWER', 88), ('STAIRS_-_GOING_DOWN', 87), ('STAIRS_-_GOING_UP', 78), ('IN_A_MEETING', 63), ('WATCHING_TV', 62), ('ON_A_BUS', 54), ('SHOPPING', 48), ('IN_A_CAR', 42), ('FIX_running', 0), ('BICYCLING', 0), ('LAB_WORK', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('PHONE_IN_POCKET', 0), ('OR_exercise', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('COMPUTER_WORK', 0), ('AT_THE_GYM', 0), ('ELEVATOR', 0), ('PHONE_IN_HAND', 0), ('PHONE_IN_BAG', 0)]
# Reading FDAA70A1-42A3-4E3F-9AE3-3FDA412E03BF.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (4973, 225)
# Label shape for user (Len minutes, num labels):  (4973, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('SITTING', 1096), ('PHONE_ON_TABLE', 984), ('AT_SCHOOL', 929), ('PHONE_IN_POCKET', 878), ('LYING_DOWN', 516), ('OR_standing', 323), ('COMPUTER_WORK', 234), ('FIX_walking', 223), ('DRIVE_-_I_M_THE_DRIVER', 147), ('EATING', 127), ('PHONE_IN_HAND', 37), ('TALKING', 21), ('WATCHING_TV', 15), ('FIX_running', 0), ('BICYCLING', 0), ('SLEEPING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('IN_A_MEETING', 0), ('LOC_main_workplace', 0), ('OR_indoors', 0), ('OR_outside', 0), ('IN_A_CAR', 0), ('ON_A_BUS', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('LOC_home', 0), ('FIX_restaurant', 0), ('OR_exercise', 0), ('COOKING', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('TOILET', 0), ('GROOMING', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_BAG', 0), ('WITH_CO-WORKERS', 0), ('WITH_FRIENDS', 0)]
# Reading BEF6C611-50DA-4971-A040-87FB979F3FC1.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (3451, 225)
# Label shape for user (Len minutes, num labels):  (3451, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('SITTING', 1265), ('LOC_main_workplace', 719), ('OR_indoors', 442), ('LOC_home', 442), ('WATCHING_TV', 420), ('LYING_DOWN', 339), ('COMPUTER_WORK', 213), ('EATING', 172), ('DRIVE_-_I_M_THE_DRIVER', 118), ('FIX_walking', 117), ('OR_standing', 114), ('FIX_restaurant', 109), ('DRIVE_-_I_M_A_PASSENGER', 95), ('DOING_LAUNDRY', 35), ('IN_A_MEETING', 31), ('TALKING', 27), ('IN_A_CAR', 26), ('FIX_running', 0), ('BICYCLING', 0), ('SLEEPING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('OR_outside', 0), ('ON_A_BUS', 0), ('PHONE_IN_POCKET', 0), ('OR_exercise', 0), ('COOKING', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('CLEANING', 0), ('WASHING_DISHES', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('TOILET', 0), ('GROOMING', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('AT_SCHOOL', 0), ('PHONE_IN_HAND', 0), ('PHONE_IN_BAG', 0), ('PHONE_ON_TABLE', 0), ('WITH_CO-WORKERS', 0), ('WITH_FRIENDS', 0)]
# Reading 098A72A5-E3E5-4F54-A152-BBDA0DF7B694.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (6813, 225)
# Label shape for user (Len minutes, num labels):  (6813, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('LOC_home', 2809), ('OR_indoors', 2759), ('LYING_DOWN', 2724), ('LOC_main_workplace', 2322), ('SITTING', 2246), ('SLEEPING', 1742), ('COMPUTER_WORK', 1346), ('AT_SCHOOL', 890), ('PHONE_ON_TABLE', 505), ('OR_exercise', 350), ('PHONE_IN_HAND', 242), ('TALKING', 221), ('FIX_walking', 187), ('OR_standing', 158), ('SURFING_THE_INTERNET', 136), ('BICYCLING', 120), ('IN_A_CAR', 117), ('DRIVE_-_I_M_THE_DRIVER', 108), ('LAB_WORK', 89), ('IN_A_MEETING', 81), ('DRIVE_-_I_M_A_PASSENGER', 34), ('FIX_running', 33), ('TOILET', 26), ('COOKING', 25), ('EATING', 25), ('GROOMING', 16), ('OR_outside', 14), ('DRESSING', 10), ('LOC_beach', 8), ('WATCHING_TV', 1), ('STAIRS_-_GOING_UP', 1), ('STAIRS_-_GOING_DOWN', 1), ('IN_CLASS', 0), ('ON_A_BUS', 0), ('FIX_restaurant', 0), ('PHONE_IN_POCKET', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('SINGING', 0), ('AT_THE_GYM', 0), ('ELEVATOR', 0), ('PHONE_IN_BAG', 0), ('WITH_CO-WORKERS', 0), ('WITH_FRIENDS', 0)]
# Reading 78A91A4E-4A51-4065-BDA7-94755F0BB3BB.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (11996, 225)
# Label shape for user (Len minutes, num labels):  (11996, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 6464), ('LOC_home', 6422), ('SITTING', 3706), ('LYING_DOWN', 2546), ('SLEEPING', 2399), ('OR_standing', 1580), ('COMPUTER_WORK', 1530), ('AT_SCHOOL', 927), ('OR_exercise', 662), ('DRIVE_-_I_M_THE_DRIVER', 505), ('AT_THE_GYM', 372), ('BICYCLING', 290), ('OR_outside', 205), ('FIX_walking', 193), ('FIX_restaurant', 184), ('AT_A_BAR', 75), ('DRIVE_-_I_M_A_PASSENGER', 23), ('FIX_running', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('IN_A_MEETING', 0), ('LOC_main_workplace', 0), ('IN_A_CAR', 0), ('ON_A_BUS', 0), ('PHONE_IN_POCKET', 0), ('COOKING', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('WATCHING_TV', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_PARTY', 0), ('LOC_beach', 0), ('SINGING', 0), ('TALKING', 0), ('EATING', 0), ('TOILET', 0), ('GROOMING', 0), ('DRESSING', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_HAND', 0), ('PHONE_IN_BAG', 0), ('PHONE_ON_TABLE', 0), ('WITH_CO-WORKERS', 0), ('WITH_FRIENDS', 0)]
# Reading B7F9D634-263E-4A97-87F9-6FFB4DDCB36C.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (9383, 225)
# Label shape for user (Len minutes, num labels):  (9383, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('PHONE_ON_TABLE', 5581), ('SITTING', 4226), ('LYING_DOWN', 2573), ('OR_indoors', 2339), ('SLEEPING', 2310), ('LOC_main_workplace', 2228), ('COMPUTER_WORK', 1682), ('WATCHING_TV', 1433), ('OR_standing', 1079), ('EATING', 471), ('PHONE_IN_BAG', 470), ('AT_SCHOOL', 285), ('PHONE_IN_POCKET', 267), ('FIX_walking', 261), ('DRIVE_-_I_M_THE_DRIVER', 239), ('IN_A_MEETING', 198), ('PHONE_IN_HAND', 179), ('TALKING', 86), ('WASHING_DISHES', 77), ('COOKING', 69), ('ON_A_BUS', 35), ('LOC_home', 28), ('GROOMING', 10), ('FIX_running', 2), ('OR_exercise', 2), ('ELEVATOR', 1), ('BICYCLING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('OR_outside', 0), ('IN_A_CAR', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('TOILET', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('WITH_CO-WORKERS', 0), ('WITH_FRIENDS', 0)]
# Reading 9DC38D04-E82E-4F29-AB52-B476535226F2.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (9686, 225)
# Label shape for user (Len minutes, num labels):  (9686, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 7903), ('LOC_home', 5106), ('SITTING', 3880), ('PHONE_ON_TABLE', 3159), ('LYING_DOWN', 2747), ('TALKING', 2711), ('SLEEPING', 2552), ('PHONE_IN_POCKET', 2029), ('OR_standing', 1667), ('AT_SCHOOL', 1532), ('WITH_FRIENDS', 1506), ('OR_outside', 1062), ('WATCHING_TV', 710), ('OR_exercise', 676), ('PHONE_IN_HAND', 557), ('BICYCLING', 540), ('SURFING_THE_INTERNET', 512), ('EATING', 503), ('FIX_walking', 494), ('PHONE_IN_BAG', 414), ('IN_CLASS', 409), ('DRINKING__ALCOHOL_', 351), ('AT_A_PARTY', 291), ('DRESSING', 254), ('GROOMING', 226), ('DRIVE_-_I_M_THE_DRIVER', 218), ('COOKING', 173), ('CLEANING', 155), ('COMPUTER_WORK', 106), ('TOILET', 91), ('DRIVE_-_I_M_A_PASSENGER', 75), ('FIX_running', 68), ('BATHING_-_SHOWER', 55), ('ON_A_BUS', 26), ('IN_A_MEETING', 24), ('SHOPPING', 15), ('FIX_restaurant', 11), ('WASHING_DISHES', 10), ('LAB_WORK', 0), ('LOC_main_workplace', 0), ('IN_A_CAR', 0), ('STROLLING', 0), ('DOING_LAUNDRY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('WITH_CO-WORKERS', 0)]
# Reading 81536B0A-8DBF-4D8A-AC24-9543E2E4C8E0.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (6407, 225)
# Label shape for user (Len minutes, num labels):  (6407, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 2580), ('LYING_DOWN', 2297), ('SLEEPING', 2269), ('SITTING', 2143), ('LOC_home', 1782), ('COMPUTER_WORK', 1377), ('SURFING_THE_INTERNET', 1293), ('WITH_FRIENDS', 959), ('EATING', 746), ('TALKING', 687), ('WATCHING_TV', 607), ('BICYCLING', 579), ('OR_exercise', 579), ('DRIVE_-_I_M_THE_DRIVER', 557), ('OR_standing', 395), ('DRINKING__ALCOHOL_', 301), ('SHOPPING', 226), ('OR_outside', 219), ('STROLLING', 219), ('FIX_walking', 78), ('COOKING', 77), ('DRIVE_-_I_M_A_PASSENGER', 25), ('BATHING_-_SHOWER', 20), ('AT_A_BAR', 14), ('CLEANING', 11), ('GROOMING', 11), ('PHONE_IN_HAND', 7), ('FIX_running', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('IN_A_MEETING', 0), ('LOC_main_workplace', 0), ('IN_A_CAR', 0), ('ON_A_BUS', 0), ('FIX_restaurant', 0), ('PHONE_IN_POCKET', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('AT_A_PARTY', 0), ('LOC_beach', 0), ('SINGING', 0), ('TOILET', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('AT_SCHOOL', 0), ('PHONE_IN_BAG', 0), ('PHONE_ON_TABLE', 0), ('WITH_CO-WORKERS', 0)]
# Reading 5EF64122-B513-46AE-BCF1-E62AAC285D2C.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (3911, 225)
# Label shape for user (Len minutes, num labels):  (3911, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 2827), ('PHONE_ON_TABLE', 2668), ('LOC_home', 2158), ('SITTING', 1312), ('LYING_DOWN', 1284), ('SLEEPING', 1107), ('LOC_main_workplace', 908), ('TALKING', 874), ('OR_standing', 620), ('WATCHING_TV', 570), ('EATING', 383), ('LAB_WORK', 313), ('COMPUTER_WORK', 289), ('WITH_CO-WORKERS', 286), ('DRIVE_-_I_M_THE_DRIVER', 265), ('GROOMING', 212), ('COOKING', 182), ('OR_outside', 173), ('IN_A_MEETING', 139), ('FIX_walking', 132), ('PHONE_IN_HAND', 105), ('WASHING_DISHES', 67), ('PHONE_IN_POCKET', 33), ('TOILET', 31), ('DOING_LAUNDRY', 8), ('FIX_running', 0), ('BICYCLING', 0), ('IN_CLASS', 0), ('IN_A_CAR', 0), ('ON_A_BUS', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('OR_exercise', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('CLEANING', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('AT_SCHOOL', 0), ('PHONE_IN_BAG', 0), ('WITH_FRIENDS', 0)]
# Reading C48CE857-A0DD-4DDB-BEA5-3A25449B2153.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (5092, 225)
# Label shape for user (Len minutes, num labels):  (5092, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('LOC_home', 3348), ('OR_indoors', 2988), ('PHONE_ON_TABLE', 2318), ('SITTING', 2138), ('SURFING_THE_INTERNET', 1736), ('COMPUTER_WORK', 1704), ('LYING_DOWN', 1242), ('LOC_main_workplace', 1236), ('SLEEPING', 1031), ('TALKING', 875), ('OR_standing', 778), ('COOKING', 356), ('EATING', 280), ('WASHING_DISHES', 272), ('FIX_walking', 268), ('PHONE_IN_HAND', 231), ('TOILET', 208), ('OR_exercise', 199), ('CLEANING', 184), ('WITH_FRIENDS', 156), ('AT_SCHOOL', 135), ('WATCHING_TV', 131), ('OR_outside', 128), ('FIX_running', 113), ('AT_THE_GYM', 113), ('AT_A_PARTY', 104), ('BATHING_-_SHOWER', 91), ('DOING_LAUNDRY', 90), ('PHONE_IN_POCKET', 86), ('PHONE_IN_BAG', 82), ('IN_A_CAR', 79), ('DRESSING', 77), ('STROLLING', 69), ('SHOPPING', 68), ('ON_A_BUS', 46), ('DRIVE_-_I_M_A_PASSENGER', 38), ('ELEVATOR', 15), ('IN_A_MEETING', 13), ('FIX_restaurant', 3), ('BICYCLING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRINKING__ALCOHOL_', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('GROOMING', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('WITH_CO-WORKERS', 0)]
# Reading CDA3BBF7-6631-45E8-85BA-EEB416B32A3C.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (2860, 225)
# Label shape for user (Len minutes, num labels):  (2860, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 2616), ('LOC_home', 2616), ('LYING_DOWN', 1261), ('SLEEPING', 1260), ('SITTING', 1010), ('WATCHING_TV', 462), ('OR_standing', 456), ('WITH_FRIENDS', 226), ('TALKING', 179), ('EATING', 178), ('GROOMING', 139), ('FIX_walking', 107), ('SHOPPING', 102), ('CLEANING', 68), ('COOKING', 59), ('DRIVE_-_I_M_THE_DRIVER', 48), ('WASHING_DISHES', 32), ('DOING_LAUNDRY', 28), ('AT_SCHOOL', 25), ('BATHING_-_SHOWER', 22), ('IN_A_MEETING', 21), ('TOILET', 5), ('FIX_running', 0), ('BICYCLING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('LOC_main_workplace', 0), ('OR_outside', 0), ('IN_A_CAR', 0), ('ON_A_BUS', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('PHONE_IN_POCKET', 0), ('OR_exercise', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('COMPUTER_WORK', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_HAND', 0), ('PHONE_IN_BAG', 0), ('PHONE_ON_TABLE', 0), ('WITH_CO-WORKERS', 0)]
# Reading 61976C24-1C50-4355-9C49-AAE44A7D09F6.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (8730, 225)
# Label shape for user (Len minutes, num labels):  (8730, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('PHONE_ON_TABLE', 4300), ('SITTING', 3467), ('OR_indoors', 1591), ('COMPUTER_WORK', 1492), ('SLEEPING', 1432), ('LYING_DOWN', 1394), ('LOC_main_workplace', 1020), ('AT_SCHOOL', 932), ('TALKING', 540), ('PHONE_IN_BAG', 538), ('OR_standing', 467), ('PHONE_IN_HAND', 452), ('FIX_walking', 412), ('EATING', 373), ('SURFING_THE_INTERNET', 303), ('IN_A_CAR', 298), ('DRIVE_-_I_M_A_PASSENGER', 298), ('OR_outside', 248), ('PHONE_IN_POCKET', 215), ('WATCHING_TV', 199), ('IN_A_MEETING', 181), ('CLEANING', 173), ('GROOMING', 70), ('DRESSING', 45), ('BATHING_-_SHOWER', 36), ('COOKING', 15), ('FIX_restaurant', 13), ('WASHING_DISHES', 4), ('DRINKING__ALCOHOL_', 2), ('FIX_running', 1), ('OR_exercise', 1), ('BICYCLING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('ON_A_BUS', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('LOC_home', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DOING_LAUNDRY', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('TOILET', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('WITH_CO-WORKERS', 0), ('WITH_FRIENDS', 0)]
# Reading 59EEFAE0-DEB0-4FFF-9250-54D2A03D0CF2.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (7542, 225)
# Label shape for user (Len minutes, num labels):  (7542, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 4648), ('PHONE_ON_TABLE', 4585), ('LOC_home', 4504), ('SITTING', 3213), ('LYING_DOWN', 2733), ('TALKING', 2107), ('SLEEPING', 2074), ('LOC_main_workplace', 1336), ('OR_standing', 942), ('WITH_FRIENDS', 713), ('PHONE_IN_POCKET', 685), ('WATCHING_TV', 639), ('FIX_walking', 613), ('EATING', 594), ('PHONE_IN_BAG', 447), ('SURFING_THE_INTERNET', 443), ('OR_outside', 425), ('GROOMING', 249), ('COMPUTER_WORK', 209), ('COOKING', 191), ('DRESSING', 191), ('WITH_CO-WORKERS', 180), ('DRINKING__ALCOHOL_', 151), ('ON_A_BUS', 121), ('DRIVE_-_I_M_A_PASSENGER', 106), ('CLEANING', 96), ('WASHING_DISHES', 96), ('TOILET', 93), ('PHONE_IN_HAND', 71), ('IN_A_CAR', 66), ('BATHING_-_SHOWER', 59), ('DRIVE_-_I_M_THE_DRIVER', 43), ('FIX_restaurant', 16), ('FIX_running', 0), ('BICYCLING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('IN_A_MEETING', 0), ('OR_exercise', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DOING_LAUNDRY', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('AT_SCHOOL', 0)]
# Reading 33A85C34-CFE4-4732-9E73-0A7AC861B27A.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (6172, 225)
# Label shape for user (Len minutes, num labels):  (6172, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('PHONE_ON_TABLE', 2286), ('OR_indoors', 2157), ('LOC_home', 2052), ('PHONE_IN_POCKET', 1865), ('LYING_DOWN', 1810), ('SITTING', 1810), ('SLEEPING', 1317), ('LOC_main_workplace', 1132), ('COMPUTER_WORK', 635), ('OR_standing', 570), ('OR_outside', 506), ('SURFING_THE_INTERNET', 464), ('FIX_walking', 454), ('DRIVE_-_I_M_THE_DRIVER', 276), ('IN_A_CAR', 210), ('EATING', 169), ('IN_A_MEETING', 165), ('BICYCLING', 150), ('OR_exercise', 150), ('TALKING', 118), ('PHONE_IN_HAND', 113), ('WITH_CO-WORKERS', 85), ('WITH_FRIENDS', 55), ('AT_SCHOOL', 27), ('TOILET', 24), ('LAB_WORK', 21), ('DRIVE_-_I_M_A_PASSENGER', 20), ('COOKING', 15), ('FIX_running', 0), ('IN_CLASS', 0), ('ON_A_BUS', 0), ('FIX_restaurant', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('WATCHING_TV', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('GROOMING', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_BAG', 0)]
# Reading 61359772-D8D8-480D-B623-7C636EAD0C81.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (6079, 225)
# Label shape for user (Len minutes, num labels):  (6079, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('SITTING', 2731), ('OR_indoors', 2225), ('PHONE_ON_TABLE', 1892), ('LYING_DOWN', 1522), ('OR_standing', 1201), ('SLEEPING', 1093), ('WITH_FRIENDS', 919), ('PHONE_IN_POCKET', 699), ('TALKING', 631), ('LOC_main_workplace', 564), ('LOC_home', 508), ('IN_CLASS', 482), ('AT_SCHOOL', 317), ('EATING', 250), ('FIX_walking', 234), ('BICYCLING', 232), ('OR_exercise', 232), ('BATHING_-_SHOWER', 142), ('GROOMING', 78), ('DRESSING', 78), ('ON_A_BUS', 60), ('AT_A_PARTY', 45), ('OR_outside', 32), ('IN_A_MEETING', 22), ('TOILET', 13), ('FIX_running', 0), ('LAB_WORK', 0), ('IN_A_CAR', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('COOKING', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('WATCHING_TV', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('COMPUTER_WORK', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_HAND', 0), ('PHONE_IN_BAG', 0), ('WITH_CO-WORKERS', 0)]
# Reading A7599A50-24AE-46A6-8EA6-2576F1011D81.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (3898, 225)
# Label shape for user (Len minutes, num labels):  (3898, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 2451), ('SITTING', 2420), ('PHONE_ON_TABLE', 2049), ('LOC_home', 1914), ('SURFING_THE_INTERNET', 1434), ('PHONE_IN_BAG', 1387), ('AT_SCHOOL', 770), ('TALKING', 666), ('FIX_walking', 507), ('OR_standing', 501), ('DRIVE_-_I_M_THE_DRIVER', 424), ('IN_A_CAR', 388), ('LYING_DOWN', 352), ('SLEEPING', 352), ('OR_outside', 299), ('SHOPPING', 263), ('OR_exercise', 242), ('EATING', 156), ('STROLLING', 148), ('ON_A_BUS', 86), ('PHONE_IN_HAND', 72), ('IN_A_MEETING', 44), ('GROOMING', 30), ('DRESSING', 30), ('BATHING_-_SHOWER', 18), ('FIX_restaurant', 15), ('WITH_FRIENDS', 15), ('LOC_main_workplace', 1), ('WITH_CO-WORKERS', 1), ('FIX_running', 0), ('BICYCLING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('PHONE_IN_POCKET', 0), ('COOKING', 0), ('DRINKING__ALCOHOL_', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('WATCHING_TV', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('COMPUTER_WORK', 0), ('TOILET', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0)]
# Reading 806289BC-AD52-4CC1-806C-0CDB14D65EB6.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (9242, 225)
# Label shape for user (Len minutes, num labels):  (9242, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 8093), ('LOC_home', 6798), ('PHONE_ON_TABLE', 4613), ('LYING_DOWN', 3696), ('SITTING', 3668), ('SLEEPING', 2702), ('WATCHING_TV', 1327), ('AT_SCHOOL', 1190), ('SURFING_THE_INTERNET', 1128), ('TALKING', 1103), ('OR_standing', 1053), ('WITH_FRIENDS', 1040), ('COMPUTER_WORK', 799), ('PHONE_IN_POCKET', 784), ('PHONE_IN_HAND', 781), ('EATING', 626), ('FIX_walking', 506), ('OR_outside', 442), ('GROOMING', 343), ('IN_CLASS', 341), ('TOILET', 290), ('DRESSING', 273), ('PHONE_IN_BAG', 269), ('CLEANING', 234), ('BATHING_-_SHOWER', 178), ('COOKING', 175), ('LOC_main_workplace', 173), ('WITH_CO-WORKERS', 167), ('OR_exercise', 140), ('AT_THE_GYM', 139), ('WASHING_DISHES', 113), ('DRIVE_-_I_M_A_PASSENGER', 94), ('IN_A_CAR', 76), ('ON_A_BUS', 61), ('FIX_running', 50), ('IN_A_MEETING', 43), ('DOING_LAUNDRY', 28), ('ELEVATOR', 26), ('SHOPPING', 18), ('AT_A_PARTY', 15), ('STAIRS_-_GOING_DOWN', 3), ('BICYCLING', 0), ('LAB_WORK', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('FIX_restaurant', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('STAIRS_-_GOING_UP', 0)]
# Reading 0BFC35E2-4817-4865-BFA7-764742302A2D.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (3108, 225)
# Label shape for user (Len minutes, num labels):  (3108, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('SITTING', 1301), ('LOC_home', 1223), ('AT_SCHOOL', 892), ('OR_indoors', 648), ('COMPUTER_WORK', 512), ('FIX_walking', 375), ('OR_standing', 370), ('WITH_CO-WORKERS', 364), ('IN_A_MEETING', 206), ('PHONE_ON_TABLE', 200), ('OR_exercise', 141), ('DRIVE_-_I_M_THE_DRIVER', 136), ('WITH_FRIENDS', 127), ('EATING', 108), ('BICYCLING', 106), ('TALKING', 96), ('WASHING_DISHES', 80), ('PHONE_IN_POCKET', 68), ('COOKING', 65), ('WATCHING_TV', 59), ('OR_outside', 44), ('FIX_running', 35), ('PHONE_IN_HAND', 35), ('DOING_LAUNDRY', 24), ('CLEANING', 22), ('ON_A_BUS', 9), ('TOILET', 4), ('GROOMING', 4), ('LYING_DOWN', 0), ('SLEEPING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('LOC_main_workplace', 0), ('IN_A_CAR', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_BAG', 0)]
# Reading F50235E0-DD67-4F2A-B00B-1F31ADA998B9.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (2266, 225)
# Label shape for user (Len minutes, num labels):  (2266, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('SITTING', 946), ('OR_indoors', 624), ('LYING_DOWN', 577), ('LOC_home', 475), ('OR_standing', 454), ('COMPUTER_WORK', 424), ('FIX_walking', 187), ('SLEEPING', 175), ('EATING', 151), ('WATCHING_TV', 131), ('IN_A_MEETING', 78), ('DRIVE_-_I_M_A_PASSENGER', 68), ('OR_exercise', 59), ('SURFING_THE_INTERNET', 48), ('BICYCLING', 47), ('COOKING', 33), ('TOILET', 33), ('CLEANING', 32), ('BATHING_-_SHOWER', 31), ('ON_A_BUS', 30), ('SHOPPING', 28), ('WASHING_DISHES', 28), ('AT_SCHOOL', 20), ('FIX_running', 12), ('GROOMING', 10), ('DOING_LAUNDRY', 5), ('TALKING', 3), ('OR_outside', 2), ('STROLLING', 2), ('AT_A_PARTY', 2), ('LAB_WORK', 0), ('IN_CLASS', 0), ('LOC_main_workplace', 0), ('IN_A_CAR', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('FIX_restaurant', 0), ('PHONE_IN_POCKET', 0), ('DRINKING__ALCOHOL_', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_HAND', 0), ('PHONE_IN_BAG', 0), ('PHONE_ON_TABLE', 0), ('WITH_CO-WORKERS', 0), ('WITH_FRIENDS', 0)]
# Reading 1155FF54-63D3-4AB2-9863-8385D0BD0A13.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (2685, 225)
# Label shape for user (Len minutes, num labels):  (2685, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('PHONE_ON_TABLE', 2076), ('SITTING', 1543), ('OR_indoors', 1455), ('LOC_home', 1438), ('LYING_DOWN', 748), ('TALKING', 653), ('SLEEPING', 633), ('LOC_main_workplace', 591), ('PHONE_IN_POCKET', 394), ('EATING', 310), ('WATCHING_TV', 257), ('SURFING_THE_INTERNET', 242), ('OR_standing', 231), ('FIX_walking', 158), ('OR_outside', 126), ('WITH_FRIENDS', 109), ('PHONE_IN_HAND', 106), ('COMPUTER_WORK', 85), ('WITH_CO-WORKERS', 82), ('DRESSING', 57), ('COOKING', 47), ('WASHING_DISHES', 46), ('ON_A_BUS', 42), ('GROOMING', 36), ('DRIVE_-_I_M_THE_DRIVER', 35), ('TOILET', 35), ('AT_SCHOOL', 32), ('IN_A_CAR', 30), ('DRINKING__ALCOHOL_', 28), ('IN_A_MEETING', 21), ('DRIVE_-_I_M_A_PASSENGER', 20), ('BATHING_-_SHOWER', 11), ('STROLLING', 6), ('SINGING', 6), ('SHOPPING', 5), ('FIX_restaurant', 3), ('DOING_LAUNDRY', 3), ('FIX_running', 1), ('OR_exercise', 1), ('STAIRS_-_GOING_UP', 1), ('STAIRS_-_GOING_DOWN', 1), ('BICYCLING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('CLEANING', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('AT_THE_GYM', 0), ('ELEVATOR', 0), ('PHONE_IN_BAG', 0)]
# Reading 9759096F-1119-4E19-A0AD-6F16989C7E1C.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (9959, 225)
# Label shape for user (Len minutes, num labels):  (9959, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 4333), ('PHONE_ON_TABLE', 4031), ('LYING_DOWN', 4022), ('SLEEPING', 3714), ('SITTING', 2968), ('WITH_FRIENDS', 2572), ('LOC_home', 2219), ('AT_SCHOOL', 1341), ('COMPUTER_WORK', 1201), ('PHONE_IN_BAG', 988), ('LAB_WORK', 982), ('OR_standing', 659), ('PHONE_IN_POCKET', 620), ('EATING', 322), ('FIX_walking', 218), ('IN_A_CAR', 157), ('IN_A_MEETING', 131), ('BICYCLING', 109), ('OR_exercise', 109), ('GROOMING', 17), ('DRESSING', 17), ('BATHING_-_SHOWER', 8), ('SHOPPING', 7), ('COOKING', 3), ('FIX_running', 0), ('IN_CLASS', 0), ('LOC_main_workplace', 0), ('OR_outside', 0), ('ON_A_BUS', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('WATCHING_TV', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('TALKING', 0), ('TOILET', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_HAND', 0), ('WITH_CO-WORKERS', 0)]
# Reading 5152A2DF-FAF3-4BA8-9CA9-E66B32671A53.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (6617, 225)
# Label shape for user (Len minutes, num labels):  (6617, 51)
#
# Sensor feature names:
#
# Activities and counts:
# ...
# Label shape for user (Len minutes, num labels):  (6218, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 4021), ('SITTING', 3153), ('LOC_home', 3027), ('LYING_DOWN', 1554), ('PHONE_ON_TABLE', 984), ('SLEEPING', 876), ('TALKING', 766), ('FIX_walking', 765), ('IN_CLASS', 696), ('OR_standing', 486), ('COMPUTER_WORK', 417), ('PHONE_IN_HAND', 214), ('AT_SCHOOL', 207), ('EATING', 184), ('SURFING_THE_INTERNET', 168), ('IN_A_CAR', 165), ('SINGING', 148), ('LAB_WORK', 82), ('FIX_restaurant', 71), ('DRIVE_-_I_M_A_PASSENGER', 40), ('COOKING', 30), ('STAIRS_-_GOING_UP', 30), ('STAIRS_-_GOING_DOWN', 30), ('OR_outside', 23), ('PHONE_IN_BAG', 11), ('DRESSING', 6), ('TOILET', 1), ('FIX_running', 0), ('BICYCLING', 0), ('IN_A_MEETING', 0), ('LOC_main_workplace', 0), ('ON_A_BUS', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('PHONE_IN_POCKET', 0), ('OR_exercise', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('WATCHING_TV', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('GROOMING', 0), ('AT_THE_GYM', 0), ('ELEVATOR', 0), ('WITH_CO-WORKERS', 0), ('WITH_FRIENDS', 0)]
# Reading 99B204C0-DD5C-4BB7-83E8-A37281B8D769.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (6038, 225)
# Label shape for user (Len minutes, num labels):  (6038, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('PHONE_ON_TABLE', 2935), ('OR_indoors', 2731), ('LOC_home', 2729), ('SITTING', 2215), ('SLEEPING', 1913), ('LYING_DOWN', 1874), ('COMPUTER_WORK', 1336), ('LOC_main_workplace', 1097), ('OR_standing', 801), ('TALKING', 742), ('WITH_CO-WORKERS', 717), ('IN_A_MEETING', 507), ('FIX_walking', 468), ('EATING', 441), ('OR_exercise', 244), ('WITH_FRIENDS', 200), ('DRIVE_-_I_M_THE_DRIVER', 189), ('BICYCLING', 126), ('COOKING', 116), ('WATCHING_TV', 101), ('FIX_restaurant', 72), ('PHONE_IN_BAG', 62), ('CLEANING', 61), ('OR_outside', 52), ('SURFING_THE_INTERNET', 47), ('ON_A_BUS', 42), ('TOILET', 17), ('STAIRS_-_GOING_UP', 4), ('STAIRS_-_GOING_DOWN', 4), ('FIX_running', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('IN_A_CAR', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('PHONE_IN_POCKET', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('GROOMING', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('ELEVATOR', 0), ('AT_SCHOOL', 0), ('PHONE_IN_HAND', 0)]
# Reading 83CF687B-7CEC-434B-9FE8-00C3D5799BE6.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (9539, 225)
# Label shape for user (Len minutes, num labels):  (9539, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('SITTING', 4488), ('OR_indoors', 4477), ('AT_SCHOOL', 4137), ('PHONE_ON_TABLE', 3888), ('LOC_home', 3832), ('SLEEPING', 3470), ('LYING_DOWN', 3432), ('COMPUTER_WORK', 2313), ('EATING', 976), ('TALKING', 870), ('WITH_FRIENDS', 705), ('FIX_walking', 658), ('PHONE_IN_HAND', 550), ('OR_standing', 312), ('DRIVE_-_I_M_A_PASSENGER', 183), ('ON_A_BUS', 170), ('BATHING_-_SHOWER', 160), ('TOILET', 89), ('FIX_restaurant', 34), ('IN_A_MEETING', 22), ('SURFING_THE_INTERNET', 17), ('DRESSING', 10), ('FIX_running', 0), ('BICYCLING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('LOC_main_workplace', 0), ('OR_outside', 0), ('IN_A_CAR', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('PHONE_IN_POCKET', 0), ('OR_exercise', 0), ('COOKING', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('WATCHING_TV', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('GROOMING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_BAG', 0), ('WITH_CO-WORKERS', 0)]
# Reading E65577C1-8D5D-4F70-AF23-B3ADB9D3DBA3.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (3441, 225)
# Label shape for user (Len minutes, num labels):  (3441, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('LOC_home', 765), ('LOC_main_workplace', 761), ('SITTING', 757), ('OR_indoors', 755), ('LYING_DOWN', 497), ('SLEEPING', 448), ('OR_standing', 357), ('BICYCLING', 268), ('OR_exercise', 268), ('IN_A_MEETING', 175), ('COMPUTER_WORK', 167), ('FIX_walking', 147), ('EATING', 124), ('TALKING', 91), ('DRESSING', 74), ('IN_A_CAR', 45), ('PHONE_IN_BAG', 41), ('GROOMING', 40), ('BATHING_-_SHOWER', 31), ('WATCHING_TV', 20), ('CLEANING', 11), ('SURFING_THE_INTERNET', 11), ('COOKING', 10), ('TOILET', 10), ('STAIRS_-_GOING_DOWN', 3), ('WITH_CO-WORKERS', 2), ('WASHING_DISHES', 1), ('FIX_running', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('OR_outside', 0), ('ON_A_BUS', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('PHONE_IN_POCKET', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('DOING_LAUNDRY', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('ELEVATOR', 0), ('AT_SCHOOL', 0), ('PHONE_IN_HAND', 0), ('PHONE_ON_TABLE', 0), ('WITH_FRIENDS', 0)]
# Reading 0A986513-7828-4D53-AA1F-E02D6DF9561B.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (3960, 225)
# Label shape for user (Len minutes, num labels):  (3960, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('SITTING', 2253), ('OR_indoors', 2177), ('LOC_home', 1784), ('WITH_FRIENDS', 1648), ('LYING_DOWN', 1145), ('SLEEPING', 1145), ('AT_SCHOOL', 753), ('PHONE_ON_TABLE', 553), ('TALKING', 537), ('PHONE_IN_POCKET', 300), ('OR_standing', 284), ('FIX_walking', 190), ('EATING', 136), ('BATHING_-_SHOWER', 107), ('OR_outside', 77), ('DRESSING', 47), ('TOILET', 41), ('STAIRS_-_GOING_UP', 25), ('STAIRS_-_GOING_DOWN', 8), ('FIX_running', 7), ('OR_exercise', 7), ('BICYCLING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('IN_A_MEETING', 0), ('LOC_main_workplace', 0), ('IN_A_CAR', 0), ('ON_A_BUS', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('COOKING', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('WATCHING_TV', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('COMPUTER_WORK', 0), ('GROOMING', 0), ('AT_THE_GYM', 0), ('ELEVATOR', 0), ('PHONE_IN_HAND', 0), ('PHONE_IN_BAG', 0), ('WITH_CO-WORKERS', 0)]
# Reading A5CDF89D-02A2-4EC1-89F8-F534FDABDD96.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (6040, 225)
# Label shape for user (Len minutes, num labels):  (6040, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('LOC_home', 4144), ('OR_indoors', 3080), ('SITTING', 2577), ('PHONE_ON_TABLE', 1709), ('PHONE_IN_POCKET', 916), ('LYING_DOWN', 725), ('WATCHING_TV', 639), ('SLEEPING', 510), ('TALKING', 502), ('COMPUTER_WORK', 493), ('OR_standing', 454), ('PHONE_IN_HAND', 357), ('CLEANING', 210), ('FIX_walking', 205), ('TOILET', 196), ('DRIVE_-_I_M_THE_DRIVER', 169), ('EATING', 138), ('FIX_restaurant', 103), ('IN_CLASS', 82), ('WASHING_DISHES', 82), ('SURFING_THE_INTERNET', 78), ('COOKING', 68), ('BATHING_-_SHOWER', 60), ('IN_A_CAR', 59), ('AT_SCHOOL', 40), ('GROOMING', 38), ('FIX_running', 36), ('OR_exercise', 36), ('AT_THE_GYM', 36), ('SHOPPING', 22), ('OR_outside', 17), ('DRESSING', 14), ('STAIRS_-_GOING_DOWN', 12), ('STAIRS_-_GOING_UP', 6), ('DOING_LAUNDRY', 5), ('SINGING', 2), ('DRIVE_-_I_M_A_PASSENGER', 1), ('BICYCLING', 0), ('LAB_WORK', 0), ('IN_A_MEETING', 0), ('LOC_main_workplace', 0), ('ON_A_BUS', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('ELEVATOR', 0), ('PHONE_IN_BAG', 0), ('WITH_CO-WORKERS', 0), ('WITH_FRIENDS', 0)]
# Reading 7D9BB102-A612-4E2A-8E22-3159752F55D8.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (1600, 225)
# Label shape for user (Len minutes, num labels):  (1600, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('AT_SCHOOL', 637), ('SITTING', 621), ('PHONE_ON_TABLE', 540), ('OR_indoors', 477), ('COMPUTER_WORK', 342), ('WITH_FRIENDS', 127), ('LOC_home', 112), ('SURFING_THE_INTERNET', 83), ('FIX_walking', 61), ('WATCHING_TV', 52), ('PHONE_IN_POCKET', 42), ('PHONE_IN_HAND', 37), ('IN_A_MEETING', 24), ('OR_outside', 20), ('FIX_restaurant', 14), ('STROLLING', 12), ('TOILET', 2), ('OR_standing', 2), ('SINGING', 1), ('GROOMING', 1), ('LYING_DOWN', 0), ('FIX_running', 0), ('BICYCLING', 0), ('SLEEPING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('LOC_main_workplace', 0), ('IN_A_CAR', 0), ('ON_A_BUS', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('OR_exercise', 0), ('COOKING', 0), ('SHOPPING', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('TALKING', 0), ('EATING', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_BAG', 0), ('WITH_CO-WORKERS', 0)]
# Reading 24E40C4C-A349-4F9F-93AB-01D00FB994AF.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (4771, 225)
# Label shape for user (Len minutes, num labels):  (4771, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('SITTING', 1728), ('PHONE_IN_POCKET', 1363), ('PHONE_ON_TABLE', 1137), ('LOC_home', 1084), ('AT_SCHOOL', 982), ('OR_standing', 978), ('TALKING', 958), ('LOC_main_workplace', 697), ('OR_indoors', 631), ('COMPUTER_WORK', 517), ('DRIVE_-_I_M_THE_DRIVER', 410), ('FIX_walking', 363), ('PHONE_IN_HAND', 362), ('EATING', 324), ('FIX_restaurant', 202), ('DRINKING__ALCOHOL_', 105), ('LYING_DOWN', 102), ('OR_outside', 99), ('STAIRS_-_GOING_DOWN', 88), ('STAIRS_-_GOING_UP', 86), ('WITH_FRIENDS', 62), ('BICYCLING', 59), ('OR_exercise', 59), ('COOKING', 58), ('SHOPPING', 44), ('DRESSING', 36), ('SINGING', 31), ('ON_A_BUS', 30), ('TOILET', 27), ('WITH_CO-WORKERS', 22), ('BATHING_-_SHOWER', 15), ('GROOMING', 14), ('DRIVE_-_I_M_A_PASSENGER', 10), ('SLEEPING', 1), ('FIX_running', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('IN_A_MEETING', 0), ('IN_A_CAR', 0), ('STROLLING', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('WATCHING_TV', 0), ('SURFING_THE_INTERNET', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('AT_THE_GYM', 0), ('ELEVATOR', 0), ('PHONE_IN_BAG', 0)]
# Reading 1DBB0F6F-1F81-4A50-9DF4-CD62ACFA4842.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (7375, 225)
# Label shape for user (Len minutes, num labels):  (7375, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 5655), ('LOC_home', 4842), ('PHONE_ON_TABLE', 4082), ('SITTING', 3441), ('LYING_DOWN', 1799), ('COMPUTER_WORK', 1657), ('SURFING_THE_INTERNET', 1340), ('SLEEPING', 1035), ('OR_standing', 980), ('TALKING', 971), ('FIX_walking', 925), ('PHONE_IN_POCKET', 871), ('OR_outside', 848), ('AT_SCHOOL', 841), ('PHONE_IN_HAND', 587), ('EATING', 461), ('IN_CLASS', 361), ('GROOMING', 253), ('DRESSING', 220), ('TOILET', 181), ('BATHING_-_SHOWER', 160), ('STROLLING', 124), ('FIX_running', 47), ('OR_exercise', 47), ('IN_A_CAR', 36), ('ON_A_BUS', 32), ('BICYCLING', 0), ('LAB_WORK', 0), ('IN_A_MEETING', 0), ('LOC_main_workplace', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('COOKING', 0), ('SHOPPING', 0), ('DRINKING__ALCOHOL_', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('WATCHING_TV', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('PHONE_IN_BAG', 0), ('WITH_CO-WORKERS', 0), ('WITH_FRIENDS', 0)]
# Reading 481F4DD2-7689-43B9-A2AA-C8772227162B.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (6691, 225)
# Label shape for user (Len minutes, num labels):  (6691, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 4876), ('SITTING', 3485), ('LOC_home', 2935), ('AT_SCHOOL', 1805), ('TALKING', 1286), ('LYING_DOWN', 1206), ('FIX_walking', 1141), ('COMPUTER_WORK', 1136), ('SLEEPING', 1097), ('PHONE_IN_HAND', 968), ('PHONE_ON_TABLE', 700), ('OR_outside', 630), ('EATING', 586), ('LOC_main_workplace', 500), ('SURFING_THE_INTERNET', 297), ('COOKING', 256), ('WITH_FRIENDS', 250), ('OR_standing', 223), ('WITH_CO-WORKERS', 219), ('STROLLING', 204), ('WATCHING_TV', 176), ('IN_A_MEETING', 135), ('GROOMING', 76), ('WASHING_DISHES', 69), ('FIX_restaurant', 62), ('ON_A_BUS', 43), ('CLEANING', 41), ('STAIRS_-_GOING_UP', 30), ('STAIRS_-_GOING_DOWN', 27), ('SHOPPING', 17), ('IN_A_CAR', 16), ('ELEVATOR', 8), ('TOILET', 1), ('FIX_running', 0), ('BICYCLING', 0), ('LAB_WORK', 0), ('IN_CLASS', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('PHONE_IN_POCKET', 0), ('OR_exercise', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('DOING_LAUNDRY', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('PHONE_IN_BAG', 0)]
# Reading CF722AA9-2533-4E51-9FEB-9EAC84EE9AAC.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (3615, 225)
# Label shape for user (Len minutes, num labels):  (3615, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 2808), ('SITTING', 2523), ('PHONE_ON_TABLE', 2446), ('AT_SCHOOL', 2381), ('LOC_main_workplace', 2240), ('SURFING_THE_INTERNET', 2120), ('LOC_home', 1671), ('TALKING', 1434), ('WITH_FRIENDS', 1326), ('EATING', 587), ('IN_A_MEETING', 482), ('LYING_DOWN', 469), ('OR_outside', 422), ('FIX_walking', 402), ('PHONE_IN_POCKET', 300), ('SINGING', 292), ('SLEEPING', 289), ('STAIRS_-_GOING_UP', 231), ('STAIRS_-_GOING_DOWN', 222), ('PHONE_IN_HAND', 181), ('PHONE_IN_BAG', 126), ('OR_standing', 122), ('WATCHING_TV', 99), ('IN_CLASS', 98), ('ELEVATOR', 45), ('FIX_running', 14), ('OR_exercise', 14), ('IN_A_CAR', 5), ('TOILET', 5), ('ON_A_BUS', 1), ('BICYCLING', 0), ('LAB_WORK', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('COOKING', 0), ('SHOPPING', 0), ('STROLLING', 0), ('DRINKING__ALCOHOL_', 0), ('BATHING_-_SHOWER', 0), ('CLEANING', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('AT_A_PARTY', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('COMPUTER_WORK', 0), ('GROOMING', 0), ('DRESSING', 0), ('AT_THE_GYM', 0), ('WITH_CO-WORKERS', 0)]
# Reading 4E98F91F-4654-42EF-B908-A3389443F2E7.features_labels.csv.gz
# Data shape input for user (Len minutes/num examples, num sensors):  (3250, 225)
# Label shape for user (Len minutes, num labels):  (3250, 51)
#
# Sensor feature names:
#
# Activities and counts:
# [('OR_indoors', 1880), ('LYING_DOWN', 1137), ('SLEEPING', 892), ('SITTING', 816), ('OR_standing', 685), ('PHONE_IN_HAND', 671), ('COMPUTER_WORK', 633), ('PHONE_ON_TABLE', 631), ('AT_A_PARTY', 558), ('SURFING_THE_INTERNET', 467), ('LOC_home', 449), ('AT_SCHOOL', 421), ('TALKING', 255), ('IN_CLASS', 254), ('DRINKING__ALCOHOL_', 188), ('OR_outside', 91), ('WATCHING_TV', 83), ('WITH_FRIENDS', 77), ('IN_A_CAR', 57), ('CLEANING', 43), ('EATING', 41), ('PHONE_IN_BAG', 40), ('ON_A_BUS', 37), ('OR_exercise', 29), ('PHONE_IN_POCKET', 25), ('TOILET', 23), ('COOKING', 20), ('FIX_walking', 16), ('GROOMING', 16), ('DRESSING', 16), ('FIX_running', 0), ('BICYCLING', 0), ('LAB_WORK', 0), ('IN_A_MEETING', 0), ('LOC_main_workplace', 0), ('DRIVE_-_I_M_THE_DRIVER', 0), ('DRIVE_-_I_M_A_PASSENGER', 0), ('FIX_restaurant', 0), ('SHOPPING', 0), ('STROLLING', 0), ('BATHING_-_SHOWER', 0), ('DOING_LAUNDRY', 0), ('WASHING_DISHES', 0), ('AT_A_BAR', 0), ('LOC_beach', 0), ('SINGING', 0), ('AT_THE_GYM', 0), ('STAIRS_-_GOING_UP', 0), ('STAIRS_-_GOING_DOWN', 0), ('ELEVATOR', 0), ('WITH_CO-WORKERS', 0)]

# %% [markdown]
# # Sequence Prediction LSTM

# %% [markdown]
# ## Embedding

# %%
def tokenize_corpus(corpus):
    corpus=corpus.split('_')
    tokens = [x for x in corpus]
    return tokens

def get_input_layer(word_idx):
    x = torch.zeros(vocabulary_size).float()
    x[word_idx] = 1.0
    return x

vocabulary_size=51
embedding_dims=10

# %%
all_tokens=[]
globs=glob.glob('dataset/sequence_strings/*')
for g in globs:
    text=open(g,'r').read()

    tokens=tokenize_corpus(text)
    tokens.pop(0) # Semantics
    all_tokens.append(tokens)

# %%
window_size=3
idx_pairs = []
# for each sentence
for sentence in all_tokens:
    for center_word_pos in range(len(sentence)):
        # for each window position
        for w in range(-window_size, window_size + 1):
            context_word_pos = center_word_pos + w
            # make soure not jump out sentence
            if context_word_pos < 0 or context_word_pos >= len(sentence) or center_word_pos == context_word_pos:
                continue
            context_word_idx = sentence[context_word_pos]
            idx_pairs.append((sentence[center_word_pos], context_word_idx))

idx_pairs = np.array(idx_pairs).astype(int) # it will be useful to have this as numpy array

# %%
W1 = V(torch.randn(embedding_dims, vocabulary_size).float(), requires_grad=True)
W2 = V(torch.randn(vocabulary_size, embedding_dims).float(), requires_grad=True)
num_epochs = 100
learning_rate = 0.001

for epo in range(num_epochs):
    loss_val = 0
    for data, target in idx_pairs:
        x = V(get_input_layer(data)).float()
        y_true = V(torch.from_numpy(np.array([target])).long())

        z1 = torch.matmul(W1, x)
        z2 = torch.matmul(W2, z1)
    
        log_softmax = F.log_softmax(z2, dim=0)

        loss = F.nll_loss(log_softmax.view(1,-1), y_true)
        
        loss_val += loss.data
        loss.backward()
        W1.data -= learning_rate * W1.grad.data
        W2.data -= learning_rate * W2.grad.data

        W1.grad.data.zero_()
        W2.grad.data.zero_()
    if epo % 10 == 0:    
        print(f'Loss at epo {epo}: {loss_val/len(idx_pairs)}')
# Out:
# Loss at epo 0: 2.8326637744903564

# %%
W1_np=W1.detach().numpy()
W2_np=W2.detach().numpy().T
embed_np=(W1_np+W2_np)/2.

from sklearn.manifold import TSNE
X_embedded=TSNE(n_components=2,verbose=2,learning_rate=500,n_iter=3000,random_state=10).fit_transform(embed_np)

# %%
sns.set_context('notebook',font_scale=1.1)
sns.set_style('ticks')
sns.lmplot(x='_DIM_1_',
           y='_DIM_2_'.
           data)

# %%
plt.scatter(X_embedded[:, 0], X_embedded[:, 1])
