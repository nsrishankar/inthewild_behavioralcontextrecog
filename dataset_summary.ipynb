# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# Required imports
import datetime
import os
import numpy as np
import pandas as pd
import gzip
import glob
import pickle
import copy
import math
from io import StringIO
import importlib.machinery

# %%
prefix='dataset/Extrasensory_uuid_fl_uTAR/'
user_sample='3600D531-0C55-44A7-AE95-A7A38519464E.features_labels'

# %%
# Dataset parsers for header/ body for CSVs
def parse_header_of_csv(csv_str):
    # Isolate the headline columns:
    headline = csv_str[:csv_str.index('\n')];
    columns = headline.split(',');

    # The first column should be timestamp:
    assert columns[0] == 'timestamp';
    # The last column should be label_source:
    assert columns[-1] == 'label_source';
    
    # Search for the column of the first label:
    for (ci,col) in enumerate(columns):
        if col.startswith('label:'):
            first_label_ind = ci;
            break;
        pass;

    # Feature columns come after timestamp and before the labels:
    feature_names = columns[1:first_label_ind];
    # Then come the labels, till the one-before-last column:
    label_names = columns[first_label_ind:-1];
    for (li,label) in enumerate(label_names):
        # In the CSV the label names appear with prefix 'label:', but we don't need it after reading the data:
        assert label.startswith('label:');
        label_names[li] = label.replace('label:','');
        pass;
    
    return (feature_names,label_names);

def parse_body_of_csv(csv_str,n_features):
    # Read the entire CSV body into a single numeric matrix:
    full_table = np.loadtxt(StringIO(csv_str),delimiter=',',skiprows=1);
    
    # Timestamp is the primary key for the records (examples):
    timestamps = full_table[:,0].astype(int);
    
    # Read the sensor features:
    X = full_table[:,1:(n_features+1)];
    
    # Read the binary label values, and the 'missing label' indicators:
    trinary_labels_mat = full_table[:,(n_features+1):-1]; # This should have values of either 0., 1. or NaN
    M = np.isnan(trinary_labels_mat); # M is the missing label matrix
    
    #print("M matrix shape:",M.shape)
    #print("Matrix: ",np.argwhere(M))
    trinary_labels_mat[M]=-1 # Replace NaNs with -1.0 for which we then apply a mask
    unique,counts=np.unique(trinary_labels_mat,return_counts=True)
    print(*zip(unique,counts)) 
    
#     Y = np.where(M,0,trinary_labels_mat) > 0.; # Y is the label matrix
    
    return (X,trinary_labels_mat,M,timestamps);

def read_user_data(directory):
    print('Reading {}'.format(directory.split("/")[-1]))

    # Read the entire csv file of the user:
    with gzip.open(directory,'rb') as fid:
        csv_str = fid.read();
        csv_str = csv_str.decode("utf-8")
        pass;

    (feature_names,label_names) = parse_header_of_csv(csv_str);
    n_features = len(feature_names);
    (X,Y,M,timestamps) = parse_body_of_csv(csv_str,n_features);

    return (X,Y,M,timestamps,feature_names,label_names);

# %%
# Reading sample data
sample_loc='{}/{}.csv.gz'.format(prefix,user_sample)
x_user,y_user,missedlabel_user,tstamp_user,featurename_user,labelname_user=read_user_data(sample_loc)
# Out:
# Reading 3600D531-0C55-44A7-AE95-A7A38519464E.features_labels.csv.gz
# (-1.0, 148794) (0.0, 97289) (1.0, 19270)

# %%
globs=glob.glob(prefix+'*')

# %%
df=pd.DataFrame(data=None,columns=featurename_user)
df_label=pd.DataFrame(data=None,columns=labelname_user)
for g in globs:
    print(g)
    (x_user_train,y_user_train,missed_label_user,tstamp_user,featurename_user,labelname_user)=read_user_data(g)
    temp_df=pd.DataFrame(x_user_train,columns=featurename_user)
    temp_df_label=pd.DataFrame(y_user_train,columns=labelname_user)
    df=df.append(temp_df,ignore_index=True)
    df_label=df_label.append(temp_df_label,ignore_index=True)
# Out:
# dataset/Extrasensory_uuid_fl_uTAR/3600D531-0C55-44A7-AE95-A7A38519464E.features_labels.csv.gz
# Reading 3600D531-0C55-44A7-AE95-A7A38519464E.features_labels.csv.gz
# (-1.0, 148794) (0.0, 97289) (1.0, 19270)
# dataset/Extrasensory_uuid_fl_uTAR/8023FE1A-D3B0-4E2C-A57A-9321B7FC755F.features_labels.csv.gz
# Reading 8023FE1A-D3B0-4E2C-A57A-9321B7FC755F.features_labels.csv.gz
# (-1.0, 224199) (0.0, 219348) (1.0, 25092)
# dataset/Extrasensory_uuid_fl_uTAR/86A4F379-B305-473D-9D83-FC7D800180EF.features_labels.csv.gz
# Reading 86A4F379-B305-473D-9D83-FC7D800180EF.features_labels.csv.gz
# (-1.0, 431262) (0.0, 98651) (1.0, 17725)
# dataset/Extrasensory_uuid_fl_uTAR/1538C99F-BA1E-4EFB-A949-6C7C47701B20.features_labels.csv.gz
# Reading 1538C99F-BA1E-4EFB-A949-6C7C47701B20.features_labels.csv.gz
# (-1.0, 179351) (0.0, 131384) (1.0, 23264)
# dataset/Extrasensory_uuid_fl_uTAR/11B5EC4D-4133-4289-B475-4E737182A406.features_labels.csv.gz
# Reading 11B5EC4D-4133-4289-B475-4E737182A406.features_labels.csv.gz
# (-1.0, 272896) (0.0, 151275) (1.0, 26924)
# dataset/Extrasensory_uuid_fl_uTAR/74B86067-5D4B-43CF-82CF-341B76BEA0F4.features_labels.csv.gz
# Reading 74B86067-5D4B-43CF-82CF-341B76BEA0F4.features_labels.csv.gz
# (-1.0, 187788) (0.0, 155026) (1.0, 29384)
# dataset/Extrasensory_uuid_fl_uTAR/4FC32141-E888-4BFF-8804-12559A491D8C.features_labels.csv.gz
# Reading 4FC32141-E888-4BFF-8804-12559A491D8C.features_labels.csv.gz
# (-1.0, 124784) (0.0, 112926) (1.0, 16219)
# dataset/Extrasensory_uuid_fl_uTAR/B9724848-C7E2-45F4-9B3F-A1F38D864495.features_labels.csv.gz
# Reading B9724848-C7E2-45F4-9B3F-A1F38D864495.features_labels.csv.gz
# (-1.0, 165608) (0.0, 194813) (1.0, 28505)
# dataset/Extrasensory_uuid_fl_uTAR/A76A5AF5-5A93-4CF2-A16E-62353BB70E8A.features_labels.csv.gz
# Reading A76A5AF5-5A93-4CF2-A16E-62353BB70E8A.features_labels.csv.gz
# (-1.0, 110357) (0.0, 241166) (1.0, 31997)
# dataset/Extrasensory_uuid_fl_uTAR/96A358A0-FFF2-4239-B93E-C7425B901B47.features_labels.csv.gz
# Reading 96A358A0-FFF2-4239-B93E-C7425B901B47.features_labels.csv.gz
# (-1.0, 250655) (0.0, 37520) (1.0, 8594)
# dataset/Extrasensory_uuid_fl_uTAR/665514DE-49DC-421F-8DCB-145D0B2609AD.features_labels.csv.gz
# Reading 665514DE-49DC-421F-8DCB-145D0B2609AD.features_labels.csv.gz
# (-1.0, 274316) (0.0, 166916) (1.0, 26285)
# dataset/Extrasensory_uuid_fl_uTAR/BE3CA5A6-A561-4BBD-B7C9-5DF6805400FC.features_labels.csv.gz
# Reading BE3CA5A6-A561-4BBD-B7C9-5DF6805400FC.features_labels.csv.gz
# (-1.0, 275018) (0.0, 137754) (1.0, 10987)
# dataset/Extrasensory_uuid_fl_uTAR/A5A30F76-581E-4757-97A2-957553A2C6AA.features_labels.csv.gz
# Reading A5A30F76-581E-4757-97A2-957553A2C6AA.features_labels.csv.gz
# (-1.0, 39134) (0.0, 39676) (1.0, 6207)
# dataset/Extrasensory_uuid_fl_uTAR/27E04243-B138-4F40-A164-F40B60165CF3.features_labels.csv.gz
# Reading 27E04243-B138-4F40-A164-F40B60165CF3.features_labels.csv.gz
# (-1.0, 177844) (0.0, 61050) (1.0, 12383)
# dataset/Extrasensory_uuid_fl_uTAR/0E6184E1-90C0-48EE-B25A-F1ECB7B9714E.features_labels.csv.gz
# Reading 0E6184E1-90C0-48EE-B25A-F1ECB7B9714E.features_labels.csv.gz
# (-1.0, 163856) (0.0, 192547) (1.0, 27168)
# dataset/Extrasensory_uuid_fl_uTAR/FDAA70A1-42A3-4E3F-9AE3-3FDA412E03BF.features_labels.csv.gz
# Reading FDAA70A1-42A3-4E3F-9AE3-3FDA412E03BF.features_labels.csv.gz
# (-1.0, 225992) (0.0, 22101) (1.0, 5530)
# dataset/Extrasensory_uuid_fl_uTAR/BEF6C611-50DA-4971-A040-87FB979F3FC1.features_labels.csv.gz
# Reading BEF6C611-50DA-4971-A040-87FB979F3FC1.features_labels.csv.gz
# (-1.0, 142967) (0.0, 28350) (1.0, 4684)
# dataset/Extrasensory_uuid_fl_uTAR/098A72A5-E3E5-4F54-A152-BBDA0DF7B694.features_labels.csv.gz
# Reading 098A72A5-E3E5-4F54-A152-BBDA0DF7B694.features_labels.csv.gz
# (-1.0, 183284) (0.0, 144833) (1.0, 19346)
# dataset/Extrasensory_uuid_fl_uTAR/78A91A4E-4A51-4065-BDA7-94755F0BB3BB.features_labels.csv.gz
# Reading 78A91A4E-4A51-4065-BDA7-94755F0BB3BB.features_labels.csv.gz
# (-1.0, 470052) (0.0, 113661) (1.0, 28083)
# dataset/Extrasensory_uuid_fl_uTAR/B7F9D634-263E-4A97-87F9-6FFB4DDCB36C.features_labels.csv.gz
# Reading B7F9D634-263E-4A97-87F9-6FFB4DDCB36C.features_labels.csv.gz
# (-1.0, 276257) (0.0, 176145) (1.0, 26131)
# dataset/Extrasensory_uuid_fl_uTAR/9DC38D04-E82E-4F29-AB52-B476535226F2.features_labels.csv.gz
# Reading 9DC38D04-E82E-4F29-AB52-B476535226F2.features_labels.csv.gz
# (-1.0, 148758) (0.0, 302410) (1.0, 42818)
# dataset/Extrasensory_uuid_fl_uTAR/81536B0A-8DBF-4D8A-AC24-9543E2E4C8E0.features_labels.csv.gz
# Reading 81536B0A-8DBF-4D8A-AC24-9543E2E4C8E0.features_labels.csv.gz
# (-1.0, 184955) (0.0, 121744) (1.0, 20058)
# dataset/Extrasensory_uuid_fl_uTAR/5EF64122-B513-46AE-BCF1-E62AAC285D2C.features_labels.csv.gz
# Reading 5EF64122-B513-46AE-BCF1-E62AAC285D2C.features_labels.csv.gz
# (-1.0, 116957) (0.0, 65558) (1.0, 16946)
# dataset/Extrasensory_uuid_fl_uTAR/C48CE857-A0DD-4DDB-BEA5-3A25449B2153.features_labels.csv.gz
# Reading C48CE857-A0DD-4DDB-BEA5-3A25449B2153.features_labels.csv.gz
# (-1.0, 89463) (0.0, 147200) (1.0, 23029)
# dataset/Extrasensory_uuid_fl_uTAR/CDA3BBF7-6631-45E8-85BA-EEB416B32A3C.features_labels.csv.gz
# Reading CDA3BBF7-6631-45E8-85BA-EEB416B32A3C.features_labels.csv.gz
# (-1.0, 83704) (0.0, 51236) (1.0, 10920)
# dataset/Extrasensory_uuid_fl_uTAR/61976C24-1C50-4355-9C49-AAE44A7D09F6.features_labels.csv.gz
# Reading 61976C24-1C50-4355-9C49-AAE44A7D09F6.features_labels.csv.gz
# (-1.0, 273018) (0.0, 151700) (1.0, 20512)
# dataset/Extrasensory_uuid_fl_uTAR/59EEFAE0-DEB0-4FFF-9250-54D2A03D0CF2.features_labels.csv.gz
# Reading 59EEFAE0-DEB0-4FFF-9250-54D2A03D0CF2.features_labels.csv.gz
# (-1.0, 148735) (0.0, 203268) (1.0, 32639)
# dataset/Extrasensory_uuid_fl_uTAR/33A85C34-CFE4-4732-9E73-0A7AC861B27A.features_labels.csv.gz
# Reading 33A85C34-CFE4-4732-9E73-0A7AC861B27A.features_labels.csv.gz
# (-1.0, 183636) (0.0, 112480) (1.0, 18656)
# dataset/Extrasensory_uuid_fl_uTAR/61359772-D8D8-480D-B623-7C636EAD0C81.features_labels.csv.gz
# Reading 61359772-D8D8-480D-B623-7C636EAD0C81.features_labels.csv.gz
# (-1.0, 175695) (0.0, 118132) (1.0, 16202)
# dataset/Extrasensory_uuid_fl_uTAR/A7599A50-24AE-46A6-8EA6-2576F1011D81.features_labels.csv.gz
# Reading A7599A50-24AE-46A6-8EA6-2576F1011D81.features_labels.csv.gz
# (-1.0, 91818) (0.0, 89945) (1.0, 17035)
# dataset/Extrasensory_uuid_fl_uTAR/806289BC-AD52-4CC1-806C-0CDB14D65EB6.features_labels.csv.gz
# Reading 806289BC-AD52-4CC1-806C-0CDB14D65EB6.features_labels.csv.gz
# (-1.0, 113891) (0.0, 313853) (1.0, 43598)
# dataset/Extrasensory_uuid_fl_uTAR/0BFC35E2-4817-4865-BFA7-764742302A2D.features_labels.csv.gz
# Reading 0BFC35E2-4817-4865-BFA7-764742302A2D.features_labels.csv.gz
# (-1.0, 104993) (0.0, 46261) (1.0, 7254)
# dataset/Extrasensory_uuid_fl_uTAR/F50235E0-DD67-4F2A-B00B-1F31ADA998B9.features_labels.csv.gz
# Reading F50235E0-DD67-4F2A-B00B-1F31ADA998B9.features_labels.csv.gz
# (-1.0, 51985) (0.0, 58866) (1.0, 4715)
# dataset/Extrasensory_uuid_fl_uTAR/1155FF54-63D3-4AB2-9863-8385D0BD0A13.features_labels.csv.gz
# Reading 1155FF54-63D3-4AB2-9863-8385D0BD0A13.features_labels.csv.gz
# (-1.0, 29521) (0.0, 95710) (1.0, 11704)
# dataset/Extrasensory_uuid_fl_uTAR/9759096F-1119-4E19-A0AD-6F16989C7E1C.features_labels.csv.gz
# Reading 9759096F-1119-4E19-A0AD-6F16989C7E1C.features_labels.csv.gz
# (-1.0, 325156) (0.0, 152005) (1.0, 30748)
# dataset/Extrasensory_uuid_fl_uTAR/5152A2DF-FAF3-4BA8-9CA9-E66B32671A53.features_labels.csv.gz
# Reading 5152A2DF-FAF3-4BA8-9CA9-E66B32671A53.features_labels.csv.gz
# (-1.0, 215768) (0.0, 93899) (1.0, 27800)
# dataset/Extrasensory_uuid_fl_uTAR/7CE37510-56D0-4120-A1CF-0E23351428D2.features_labels.csv.gz
# Reading 7CE37510-56D0-4120-A1CF-0E23351428D2.features_labels.csv.gz
# (-1.0, 166050) (0.0, 282892) (1.0, 48869)
# dataset/Extrasensory_uuid_fl_uTAR/59818CD2-24D7-4D32-B133-24C2FE3801E5.features_labels.csv.gz
# Reading 59818CD2-24D7-4D32-B133-24C2FE3801E5.features_labels.csv.gz
# (-1.0, 244870) (0.0, 52479) (1.0, 5948)
# dataset/Extrasensory_uuid_fl_uTAR/CA820D43-E5E2-42EF-9798-BE56F776370B.features_labels.csv.gz
# Reading CA820D43-E5E2-42EF-9798-BE56F776370B.features_labels.csv.gz
# (-1.0, 247395) (0.0, 132027) (1.0, 21693)
# dataset/Extrasensory_uuid_fl_uTAR/00EABED2-271D-49D8-B599-1D4A09240601.features_labels.csv.gz
# Reading 00EABED2-271D-49D8-B599-1D4A09240601.features_labels.csv.gz
# (-1.0, 73162) (0.0, 35620) (1.0, 7855)
# dataset/Extrasensory_uuid_fl_uTAR/40E170A7-607B-4578-AF04-F021C3B0384A.features_labels.csv.gz
# Reading 40E170A7-607B-4578-AF04-F021C3B0384A.features_labels.csv.gz
# (-1.0, 226818) (0.0, 140522) (1.0, 22759)
# dataset/Extrasensory_uuid_fl_uTAR/797D145F-3858-4A7F-A7C2-A4EB721E133C.features_labels.csv.gz
# Reading 797D145F-3858-4A7F-A7C2-A4EB721E133C.features_labels.csv.gz
# (-1.0, 149790) (0.0, 27089) (1.0, 6364)
# dataset/Extrasensory_uuid_fl_uTAR/ECECC2AB-D32F-4F90-B74C-E12A1C69BBE2.features_labels.csv.gz
# Reading ECECC2AB-D32F-4F90-B74C-E12A1C69BBE2.features_labels.csv.gz
# (-1.0, 142883) (0.0, 29344) (1.0, 7803)
# dataset/Extrasensory_uuid_fl_uTAR/2C32C23E-E30C-498A-8DD2-0EFB9150A02E.features_labels.csv.gz
# Reading 2C32C23E-E30C-498A-8DD2-0EFB9150A02E.features_labels.csv.gz
# (-1.0, 218936) (0.0, 186517) (1.0, 28863)
# dataset/Extrasensory_uuid_fl_uTAR/CCAF77F0-FABB-4F2F-9E24-D56AD0C5A82F.features_labels.csv.gz
# Reading CCAF77F0-FABB-4F2F-9E24-D56AD0C5A82F.features_labels.csv.gz
# (-1.0, 215586) (0.0, 177334) (1.0, 39152)
# dataset/Extrasensory_uuid_fl_uTAR/5119D0F8-FCA8-4184-A4EB-19421A40DE0D.features_labels.csv.gz
# Reading 5119D0F8-FCA8-4184-A4EB-19421A40DE0D.features_labels.csv.gz
# (-1.0, 110004) (0.0, 203713) (1.0, 23750)
# dataset/Extrasensory_uuid_fl_uTAR/D7D20E2E-FC78-405D-B346-DBD3FD8FC92B.features_labels.csv.gz
# Reading D7D20E2E-FC78-405D-B346-DBD3FD8FC92B.features_labels.csv.gz
# (-1.0, 173102) (0.0, 125103) (1.0, 18505)
# dataset/Extrasensory_uuid_fl_uTAR/B09E373F-8A54-44C8-895B-0039390B859F.features_labels.csv.gz
# Reading B09E373F-8A54-44C8-895B-0039390B859F.features_labels.csv.gz
# (-1.0, 312532) (0.0, 82985) (1.0, 19317)
# dataset/Extrasensory_uuid_fl_uTAR/136562B6-95B2-483D-88DC-065F28409FD2.features_labels.csv.gz
# Reading 136562B6-95B2-483D-88DC-065F28409FD2.features_labels.csv.gz
# (-1.0, 173574) (0.0, 125389) (1.0, 18155)
# dataset/Extrasensory_uuid_fl_uTAR/99B204C0-DD5C-4BB7-83E8-A37281B8D769.features_labels.csv.gz
# Reading 99B204C0-DD5C-4BB7-83E8-A37281B8D769.features_labels.csv.gz
# (-1.0, 157054) (0.0, 129041) (1.0, 21843)
# dataset/Extrasensory_uuid_fl_uTAR/83CF687B-7CEC-434B-9FE8-00C3D5799BE6.features_labels.csv.gz
# Reading 83CF687B-7CEC-434B-9FE8-00C3D5799BE6.features_labels.csv.gz
# (-1.0, 303577) (0.0, 148119) (1.0, 34793)
# dataset/Extrasensory_uuid_fl_uTAR/E65577C1-8D5D-4F70-AF23-B3ADB9D3DBA3.features_labels.csv.gz
# Reading E65577C1-8D5D-4F70-AF23-B3ADB9D3DBA3.features_labels.csv.gz
# (-1.0, 121215) (0.0, 48397) (1.0, 5879)
# dataset/Extrasensory_uuid_fl_uTAR/0A986513-7828-4D53-AA1F-E02D6DF9561B.features_labels.csv.gz
# Reading 0A986513-7828-4D53-AA1F-E02D6DF9561B.features_labels.csv.gz
# (-1.0, 129722) (0.0, 59014) (1.0, 13224)
# dataset/Extrasensory_uuid_fl_uTAR/A5CDF89D-02A2-4EC1-89F8-F534FDABDD96.features_labels.csv.gz
# Reading A5CDF89D-02A2-4EC1-89F8-F534FDABDD96.features_labels.csv.gz
# (-1.0, 162927) (0.0, 127292) (1.0, 17821)
# dataset/Extrasensory_uuid_fl_uTAR/7D9BB102-A612-4E2A-8E22-3159752F55D8.features_labels.csv.gz
# Reading 7D9BB102-A612-4E2A-8E22-3159752F55D8.features_labels.csv.gz
# (-1.0, 67562) (0.0, 10831) (1.0, 3207)
# dataset/Extrasensory_uuid_fl_uTAR/24E40C4C-A349-4F9F-93AB-01D00FB994AF.features_labels.csv.gz
# Reading 24E40C4C-A349-4F9F-93AB-01D00FB994AF.features_labels.csv.gz
# (-1.0, 136523) (0.0, 94114) (1.0, 12684)
# dataset/Extrasensory_uuid_fl_uTAR/1DBB0F6F-1F81-4A50-9DF4-CD62ACFA4842.features_labels.csv.gz
# Reading 1DBB0F6F-1F81-4A50-9DF4-CD62ACFA4842.features_labels.csv.gz
# (-1.0, 195284) (0.0, 149045) (1.0, 31796)
# dataset/Extrasensory_uuid_fl_uTAR/481F4DD2-7689-43B9-A2AA-C8772227162B.features_labels.csv.gz
# Reading 481F4DD2-7689-43B9-A2AA-C8772227162B.features_labels.csv.gz
# (-1.0, 149911) (0.0, 166829) (1.0, 24501)
# dataset/Extrasensory_uuid_fl_uTAR/CF722AA9-2533-4E51-9FEB-9EAC84EE9AAC.features_labels.csv.gz
# Reading CF722AA9-2533-4E51-9FEB-9EAC84EE9AAC.features_labels.csv.gz
# (-1.0, 80803) (0.0, 80207) (1.0, 23355)
# dataset/Extrasensory_uuid_fl_uTAR/4E98F91F-4654-42EF-B908-A3389443F2E7.features_labels.csv.gz
# Reading 4E98F91F-4654-42EF-B908-A3389443F2E7.features_labels.csv.gz
# (-1.0, 91497) (0.0, 63702) (1.0, 10551)

# %%
df.describe()
# Out:
#        raw_acc:magnitude_stats:mean  raw_acc:magnitude_stats:std  \
# count                 377056.000000                377056.000000
# mean                       1.002223                     0.038832
# std                        0.079623                     0.096109
# min                        0.018148                     0.000030
# 25%                        0.992556                     0.001709
# 50%                        1.001258                     0.003265
# 75%                        1.012745                     0.021366
# max                        3.185837                     1.936343
#
#        raw_acc:magnitude_stats:moment3  raw_acc:magnitude_stats:moment4  \
# count                    377056.000000                    377056.000000
# mean                          0.037772                         0.072804
# std                           0.113198                         0.170481
# min                          -0.493806                         0.000039
# 25%                          -0.000785                         0.002328
# 50%                           0.000772                         0.005051
# 75%                           0.009864                         0.045333
# max                           2.472750                         3.360718
#
#        raw_acc:magnitude_stats:percentile25  \
# count                         377056.000000
# mean                               0.983165
# std                                0.082960
# min                                0.015845
# 25%                                0.982671
# 50%                                0.995300
# 75%                                1.003679
# max                                1.942718
#
#        raw_acc:magnitude_stats:percentile50  \
# count                         377056.000000
# mean                               0.998471
# std                                0.076687
# min                                0.017998
# 25%                                0.991248
# 50%                                1.000116
# 75%                                1.009232
# max                                2.636697
#
#        raw_acc:magnitude_stats:percentile75  \
# count                         377056.000000
# mean                               1.016691
# std                                0.104874
# min                                0.020365
# 25%                                0.994859
# 50%                                1.003813
# 75%                                1.019163
# max                                3.958338
#
#        raw_acc:magnitude_stats:value_entropy  \
# count                          377056.000000
# mean                                2.045331
# std                                 0.616899
# min                                 0.009605
# 25%                                 1.671571
# 50%                                 2.296398
# 75%                                 2.523618
# max                                 2.971272
#
#        raw_acc:magnitude_stats:time_entropy  \
# count                         377056.000000
# mean                               6.680278
# std                                0.021246
# min                                5.460637
# 25%                                6.684369
# 50%                                6.684606
# 75%                                6.684610
# max                                6.684612
#
#        raw_acc:magnitude_spectrum:log_energy_band0  \
# count                                377056.000000
# mean                                      5.039597
# std                                       0.025809
# min                                       4.338109
# 25%                                       5.042891
# 50%                                       5.043350
# 75%                                       5.043574
# max                                       6.489025
#
#                       ...                  lf_measurements:screen_brightness  \
# count                 ...                                      220949.000000
# mean                  ...                                           0.326232
# std                   ...                                           0.296350
# min                   ...                                           0.000000
# 25%                   ...                                           0.043978
# 50%                   ...                                           0.305609
# 75%                   ...                                           0.461145
# max                   ...                                           1.000000
#
#        lf_measurements:temperature_ambient  discrete:time_of_day:between0and6  \
# count                         26450.000000                      377346.000000
# mean                             25.690594                           0.218865
# std                               3.384491                           0.413478
# min                              11.455976                           0.000000
# 25%                              23.941600                           0.000000
# 50%                              25.545454                           0.000000
# 75%                              27.650335                           0.000000
# max                             132.231644                           1.000000
#
#        discrete:time_of_day:between3and9  discrete:time_of_day:between6and12  \
# count                      377346.000000                       377346.000000
# mean                            0.206169                            0.229066
# std                             0.404554                            0.420232
# min                             0.000000                            0.000000
# 25%                             0.000000                            0.000000
# 50%                             0.000000                            0.000000
# 75%                             0.000000                            0.000000
# max                             1.000000                            1.000000
#
#        discrete:time_of_day:between9and15  \
# count                       377346.000000
# mean                             0.267147
# std                              0.442471
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              1.000000
# max                              1.000000
#
#        discrete:time_of_day:between12and18  \
# count                        377346.000000
# mean                              0.285608
# std                               0.451704
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               1.000000
# max                               1.000000
#
#        discrete:time_of_day:between15and21  \
# count                        377346.000000
# mean                              0.285624
# std                               0.451712
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               1.000000
# max                               1.000000
#
#        discrete:time_of_day:between18and24  discrete:time_of_day:between21and3
# count                        377346.000000                       377346.000000
# mean                              0.266461                            0.276425
# std                               0.442109                            0.447230
# min                               0.000000                            0.000000
# 25%                               0.000000                            0.000000
# 50%                               0.000000                            0.000000
# 75%                               1.000000                            1.000000
# max                               1.000000                            1.000000
#
# [8 rows x 225 columns]

# %%
for i in range(df_label.values.shape[-1]):
    temp_col=df_label.values[:,i]
    print("LABEL:",labelname_user[i])
    unique,counts=np.unique(temp_col,return_counts=True)
    print(*zip(unique,counts)) 
    print("-"*50)
# Out:
# LABEL: LYING_DOWN
# (-1.0, 73623) (0.0, 199513) (1.0, 104210)
# --------------------------------------------------
# LABEL: SITTING
# (-1.0, 70752) (0.0, 170238) (1.0, 136356)
# --------------------------------------------------
# LABEL: FIX_walking
# (-1.0, 70752) (0.0, 284458) (1.0, 22136)
# --------------------------------------------------
# LABEL: FIX_running
# (-1.0, 236476) (0.0, 139780) (1.0, 1090)
# --------------------------------------------------
# LABEL: BICYCLING
# (-1.0, 242163) (0.0, 130163) (1.0, 5020)
# --------------------------------------------------
# LABEL: SLEEPING
# (-1.0, 92078) (0.0, 202213) (1.0, 83055)
# --------------------------------------------------
# LABEL: LAB_WORK
# (-1.0, 327951) (0.0, 45547) (1.0, 3848)
# --------------------------------------------------
# LABEL: IN_CLASS
# (-1.0, 268283) (0.0, 102953) (1.0, 6110)
# --------------------------------------------------
# LABEL: IN_A_MEETING
# (-1.0, 146133) (0.0, 226060) (1.0, 5153)
# --------------------------------------------------
# LABEL: LOC_main_workplace
# (-1.0, 175619) (0.0, 167783) (1.0, 33944)
# --------------------------------------------------
# LABEL: OR_indoors
# (-1.0, 180540) (0.0, 12114) (1.0, 184692)
# --------------------------------------------------
# LABEL: OR_outside
# (-1.0, 225848) (0.0, 139384) (1.0, 12114)
# --------------------------------------------------
# LABEL: IN_A_CAR
# (-1.0, 202650) (0.0, 168613) (1.0, 6083)
# --------------------------------------------------
# LABEL: ON_A_BUS
# (-1.0, 208314) (0.0, 167238) (1.0, 1794)
# --------------------------------------------------
# LABEL: DRIVE_-_I_M_THE_DRIVER
# (-1.0, 215082) (0.0, 154289) (1.0, 7975)
# --------------------------------------------------
# LABEL: DRIVE_-_I_M_A_PASSENGER
# (-1.0, 246259) (0.0, 128561) (1.0, 2526)
# --------------------------------------------------
# LABEL: LOC_home
# (-1.0, 22012) (0.0, 202442) (1.0, 152892)
# --------------------------------------------------
# LABEL: FIX_restaurant
# (-1.0, 219764) (0.0, 155484) (1.0, 2098)
# --------------------------------------------------
# LABEL: PHONE_IN_POCKET
# (-1.0, 242982) (0.0, 110963) (1.0, 23401)
# --------------------------------------------------
# LABEL: OR_exercise
# (-1.0, 136509) (0.0, 232756) (1.0, 8081)
# --------------------------------------------------
# LABEL: COOKING
# (-1.0, 168000) (0.0, 205317) (1.0, 4029)
# --------------------------------------------------
# LABEL: SHOPPING
# (-1.0, 238553) (0.0, 136952) (1.0, 1841)
# --------------------------------------------------
# LABEL: STROLLING
# (-1.0, 323585) (0.0, 52955) (1.0, 806)
# --------------------------------------------------
# LABEL: DRINKING__ALCOHOL_
# (-1.0, 306563) (0.0, 69327) (1.0, 1456)
# --------------------------------------------------
# LABEL: BATHING_-_SHOWER
# (-1.0, 176226) (0.0, 199033) (1.0, 2087)
# --------------------------------------------------
# LABEL: CLEANING
# (-1.0, 217926) (0.0, 155614) (1.0, 3806)
# --------------------------------------------------
# LABEL: DOING_LAUNDRY
# (-1.0, 303374) (0.0, 73416) (1.0, 556)
# --------------------------------------------------
# LABEL: WASHING_DISHES
# (-1.0, 240872) (0.0, 135246) (1.0, 1228)
# --------------------------------------------------
# LABEL: WATCHING_TV
# (-1.0, 180994) (0.0, 183041) (1.0, 13311)
# --------------------------------------------------
# LABEL: SURFING_THE_INTERNET
# (-1.0, 184663) (0.0, 173267) (1.0, 19416)
# --------------------------------------------------
# LABEL: AT_A_PARTY
# (-1.0, 322783) (0.0, 53093) (1.0, 1470)
# --------------------------------------------------
# LABEL: AT_A_BAR
# (-1.0, 344126) (0.0, 32669) (1.0, 551)
# --------------------------------------------------
# LABEL: LOC_beach
# (-1.0, 319702) (0.0, 57059) (1.0, 585)
# --------------------------------------------------
# LABEL: SINGING
# (-1.0, 352229) (0.0, 24466) (1.0, 651)
# --------------------------------------------------
# LABEL: TALKING
# (-1.0, 97800) (0.0, 243253) (1.0, 36293)
# --------------------------------------------------
# LABEL: COMPUTER_WORK
# (-1.0, 139787) (0.0, 199478) (1.0, 38081)
# --------------------------------------------------
# LABEL: EATING
# (-1.0, 80865) (0.0, 279887) (1.0, 16594)
# --------------------------------------------------
# LABEL: TOILET
# (-1.0, 157073) (0.0, 217618) (1.0, 2655)
# --------------------------------------------------
# LABEL: GROOMING
# (-1.0, 178546) (0.0, 195736) (1.0, 3064)
# --------------------------------------------------
# LABEL: DRESSING
# (-1.0, 169438) (0.0, 205675) (1.0, 2233)
# --------------------------------------------------
# LABEL: AT_THE_GYM
# (-1.0, 332953) (0.0, 43242) (1.0, 1151)
# --------------------------------------------------
# LABEL: STAIRS_-_GOING_UP
# (-1.0, 282717) (0.0, 93831) (1.0, 798)
# --------------------------------------------------
# LABEL: STAIRS_-_GOING_DOWN
# (-1.0, 282931) (0.0, 93641) (1.0, 774)
# --------------------------------------------------
# LABEL: ELEVATOR
# (-1.0, 306150) (0.0, 70996) (1.0, 200)
# --------------------------------------------------
# LABEL: OR_standing
# (-1.0, 70752) (0.0, 268812) (1.0, 37782)
# --------------------------------------------------
# LABEL: AT_SCHOOL
# (-1.0, 118182) (0.0, 216833) (1.0, 42331)
# --------------------------------------------------
# LABEL: PHONE_IN_HAND
# (-1.0, 235643) (0.0, 127130) (1.0, 14573)
# --------------------------------------------------
# LABEL: PHONE_IN_BAG
# (-1.0, 284884) (0.0, 82261) (1.0, 10201)
# --------------------------------------------------
# LABEL: PHONE_ON_TABLE
# (-1.0, 214923) (0.0, 47386) (1.0, 115037)
# --------------------------------------------------
# LABEL: WITH_CO-WORKERS
# (-1.0, 265282) (0.0, 105840) (1.0, 6224)
# --------------------------------------------------
# LABEL: WITH_FRIENDS
# (-1.0, 211932) (0.0, 140677) (1.0, 24737)
# --------------------------------------------------
